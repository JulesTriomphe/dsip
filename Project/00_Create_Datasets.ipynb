# %% [markdown]
# # Project - Dataset creation
#
# ## Initialization

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
from time import time, ctime, strftime, gmtime

# %% [markdown]
# Import parallel computing libraries and register processors

# %%
from ipyparallel import Client
from ipyparallel.joblib import IPythonParallelBackend
from joblib import Parallel, parallel_backend, register_parallel_backend

# %% [markdown]
# On Noto, run `ipcontroller --ip="*"`

# %%
c = Client(profile='default')
print('profile:', c.profile)
print("IDs:", c.ids) # Process id numbers
bview = c.load_balanced_view()
register_parallel_backend('ipyparallel',
                          lambda : IPythonParallelBackend(view=bview))
# Out:
# profile: default
# IDs: [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Read datasets, inspired from [this study](https://www.kaggle.com/cgueret/covid-19-risk-factor-predictor/output).

# %%
predictions = pd.read_csv('Kaggle/predicted_covid19_risk_factors.csv')
targets = pd.read_csv('https://storage.googleapis.com/open-targets-data-releases/20.02/output/20.02_target_list.csv.gz',
                          compression='gzip')
diseases = pd.read_csv('https://storage.googleapis.com/open-targets-data-releases/20.02/output/20.02_disease_list.csv.gz',
                           compression='gzip')

# %% [markdown]
# Explore predictions dataset

# %%
predictions.head()
# Out:
#    Unnamed: 0                                  Risk Factors     Score
# 0           0                 Platelet storage pool disease  0.852844
# 1           1  abnormality of the urinary system physiology  0.828951
# 2           2                                 Bronchiolitis  0.781315
# 3           3                      endocrine system disease  0.774616
# 4           4                                        Hernia  0.766383

# %% [markdown]
# Describe predictions dataset

# %%
predictions['Risk Factors'].describe()
# Out:
# count                                   7217
# unique                                  7217
# top       tumor of cranial and spinal nerves
# freq                                       1
# Name: Risk Factors, dtype: object

# %%
diseases.head()
# Out:
#           efo_id                       disease_full_name  \
# 0    EFO_1000984           inflammatory breast carcinoma
# 1  MONDO_0004093           esophageal basaloid carcinoma
# 2    EFO_0006352       laryngeal squamous cell carcinoma
# 3    EFO_1000514  Salivary Gland Adenosquamous Carcinoma
# 4    EFO_1001965      pharyngeal squamous cell carcinoma
#
#    number_of_associations
# 0                     174
# 1                       1
# 2                     796
# 3                       0
# 4                     428

# %% [markdown]
# Link disease EFO code to Covid Score.

# %%
prediction_extended = predictions.merge(diseases,
                              how = 'left',
                              left_on = 'Risk Factors',
                              right_on = 'disease_full_name')[['efo_id', 'disease_full_name', 'Score']]
prediction_extended.sort_values(by = 'efo_id', inplace = True, ascending = True)
prediction_extended.reset_index(inplace=True, drop = True)
prediction_extended.head()
# Out:
#          efo_id                    disease_full_name     Score
# 0  DOID_0050890                      synucleinopathy  0.001827
# 1   EFO_0000094  B-cell acute lymphoblastic leukemia  0.001435
# 2   EFO_0000095         chronic lymphocytic leukemia  0.002511
# 3   EFO_0000096           neoplasm of mature B-cells  0.003721
# 4   EFO_0000174                        Ewing sarcoma  0.000201

# %%
print('There are {} lines (i.e. diseases) in the dataset.'.format(prediction_extended.shape[0]))
# Out:
# There are 7217 lines (i.e. diseases) in the dataset.

# %% [markdown]
# ---
#
# ## Function definitions

# %%
import glob

def dir_stats(dir_info = True,
              directory = "200_by_100/",
              file_prefix = "X_raw_disease_200_target_100_",
              file_suffix = ".csv"):
    n_files = len(glob.glob(directory + file_prefix + "*" + file_suffix))
    
    if dir_info:
        print('Number of files in directory {} : {}'.format(directory,n_files))
        
    return n_files

# %%
from datetime import datetime

def get_csvs(dir_info = True,
             directory = "200_by_100/",
             file_prefix = "X_raw_disease_200_target_100_",
             file_suffix = ".csv"):
    
    n_files = dir_stats(dir_info = dir_info,
                        directory = directory,
                        file_prefix = file_prefix,
                        file_suffix = file_suffix)

    if n_files == 0:
        done_diseases = []
        done_targets = []
        df = None
    else:
        for i in range(n_files):
            if i == 0:
                df = pd.read_csv(directory + file_prefix + str(i) + file_suffix, index_col=0)
            else:
                tmp_df = pd.read_csv(directory + file_prefix + str(i) + file_suffix, index_col=0)
                df = df.append(tmp_df)
        
        done_diseases = df.index.tolist()
        done_targets = df.columns.tolist()
        done_targets.remove('COVID')
    
    return done_diseases, done_targets, n_files, df

# %%
def create_lists(list_info = False,
                 disease_ids = prediction_extended.efo_id.tolist(),
                 target_ids = targets.ensembl_id.tolist(),
                 n_diseases = 200,
                 n_targets = 100):

    disease_list = np.random.choice(list(disease_ids), n_diseases).tolist()
    target_list = np.random.choice(list(target_ids), n_targets).tolist()

    disease_list.sort()
    target_list.sort()
    
    if list_info:
        print('Number of diseases : ', n_diseases)
        print('Number of targets :  ', n_targets)

    return disease_list, target_list

# %%
def update_lists(done_diseases: list, done_targets: list, n_diseases):
    
    disease_ids = prediction_extended[~prediction_extended.efo_id.isin(done_diseases)].efo_id.tolist()
    target_ids = targets[~targets.ensembl_id.isin(done_targets)].ensembl_id.tolist()
    
    disease_list, target_list = create_lists(list_info = False,
                                             disease_ids = disease_ids,
                                             target_ids = target_ids,
                                             n_diseases = n_diseases,
                                             n_targets = len(done_targets))
    
    return disease_list, target_list

# %% [markdown]
# Associations may be checked [here](https://www.targetvalidation.org/disease/EFO_0005774/associations) by replacing the name of the disease in the URL.
#
# Associations may also be queried with [the API](https://api.opentargets.io/v3/platform/docs/swagger-ui#/public/getAssociationFilter).
#
# Here is a sample query : [https://platform-api.opentargets.io/v3/platform/public/association/filter?disease=DOID_0050890&fields=association_score.overall&fields=target.id&fields=disease.id&size=10000](https://platform-api.opentargets.io/v3/platform/public/association/filter?disease=DOID_0050890&fields=association_score.overall&fields=target.id&fields=disease.id&size=10000)
#
# [Open Targets Data Download page](https://www.targetvalidation.org/downloads/data)

# %%
from opentargets import OpenTargetsClient

def build_dataset(disease_list: list, target_list: list):
    
    n_diseases = len(disease_list)
    n_targets = len(target_list)

    X_raw = np.zeros((n_diseases,
                      n_targets + 1))

    ot = OpenTargetsClient()
    start_time = time()
    tmp_time = time()

    print('--------------------------------------------------')
    print('BUILD Start time : ', ctime())
    print('--------------------------------------------------')

    with parallel_backend('ipyparallel'):
        
        for disease_id, disease_n in zip(disease_list, range(n_diseases)):
            
            for target_id,target_n in zip(target_list, range(n_targets)):           
                search = ot.filter_associations(disease = disease_id,
                                                target = target_id,
                                                fields = ['association_score.overall',
                                                          'target.id',
                                                          'disease.id'])
                for i, r in enumerate(search):
                    if len(search) > 0 and r['disease']['id'] == disease_id:
                        X_raw[disease_n][target_n] = r['association_score']['overall']
            X_raw[disease_n][n_targets] = prediction_extended.Score[disease_n]
            if (disease_n + 1) % 5 == 0:
                print('--', disease_n + 1, ' of ', n_diseases)
                print('Time : {:.2f} seconds.'.format(time() - start_time))
                print('Time since last print : {:.2f} seconds.'.format(time() - tmp_time))
                tmp_time = time()
    
    print('--------------------------------------------------')
    print('BUILD End time : ', ctime())
    print('--------------------------------------------------')
    return X_raw

# %%
def print_dataset(df: pd.DataFrame,
                  disease_list: list,
                  target_list: list,
                  directory = "200_by_100/",
                  file_prefix = "X_raw_disease_200_target_100_",
                  file_n = "0",
                  file_suffix = ".csv"):
    
    pd.DataFrame(df,
                 index = disease_list,
                 columns = target_list + ['COVID']
                ).to_csv(directory + file_prefix + str(file_n) + file_suffix)

# %%
def print_full_dataset(dir_info = True,
                       directory = "200_by_100/",
                       file_prefix = "X_raw_disease_200_target_100_",
                       file_suffix = ".csv"):
    
    _, _, _, df = get_csvs(dir_info = dir_info,
                           directory = directory,
                           file_prefix = file_prefix,
                           file_suffix = file_suffix)
    
    dt_string = datetime.now().strftime("%Y_%m_%d-%H_%M_%S-")
    df.to_csv(directory
              + "Full-" + dt_string
              + file_prefix
              + str(df.shape[0]) + '_by_' + str(df.shape[1])
              + file_suffix)

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# MAIN

def create_dataset(n_runs = 1,
                   dir_info = True,
                   directory = "200_by_100/",
                   file_prefix = "X_raw_disease_200_target_100_",
                   file_suffix = ".csv",
                   list_info = False,
                   disease_ids = prediction_extended.efo_id.tolist(),
                   target_ids = targets.ensembl_id.tolist(),
                   n_diseases = 100,
                   n_targets = 200):
    
    g_start_time = ctime()
    print('PROGRAM START : ', g_start_time)
    print('============================================================')
    print('============================================================')
    g_start_time_time = time()
    
    for i in range(n_runs):
        start_time = ctime()
        #print('PROGRAM START : ', start_time)
        start_time_time = time()

        done_diseases, done_targets, n_files, _ = get_csvs(dir_info = dir_info,
                                                           directory = directory,
                                                           file_prefix = file_prefix,
                                                           file_suffix = file_suffix)




        if n_files == 0:
            disease_list, target_list = create_lists(list_info = list_info,
                                                     disease_ids = disease_ids,
                                                     target_ids = target_ids,
                                                     n_diseases = n_diseases,
                                                     n_targets = n_targets)
        else:
            disease_list, _ = update_lists(done_diseases = done_diseases,
                                           done_targets = done_targets,
                                           n_diseases = n_diseases)
            while not len(disease_list) == len(set(disease_list)):
                disease_list, _ = update_lists(done_diseases = done_diseases,
                                               done_targets = done_targets,
                                               n_diseases = n_diseases)
                
            target_list = done_targets
    

        init_time = ctime()
        init_time_time = time()
        init_time_length = time() - start_time_time
        #print('INIT DONE : ', init_time)
        #print('INIT DONE IN {} seconds'.format(strftime("%H:%M:%S", gmtime(init_time_length))))

        X_raw = build_dataset(disease_list, target_list)

        print_dataset(df = X_raw,
                      disease_list = disease_list,
                      target_list = target_list,
                      directory = directory,
                      file_prefix = file_prefix,
                      file_n = n_files,
                      file_suffix = file_suffix)

        print_full_dataset(dir_info = dir_info,
                           directory = directory,
                           file_prefix = file_prefix,
                           file_suffix = file_suffix)

        done_time = ctime()
        done_time_length = time() - init_time_time
        #print('PROGRAM DONE : ', done_time)
        #print('PROGRAM DONE IN {} seconds'.format(strftime("%H:%M:%S", gmtime(done_time_length))))
    
        print('============================================================')
        print('RUN STARTED : ', start_time)
        print('INIT DONE :   ', init_time)
        print('RUN DONE :    ', done_time)
        print('============================================================')
        print('Total execution time : {}'.format(strftime("%H:%M:%S", gmtime(done_time_length))))
        print('============================================================')
    
    g_done_time = ctime()
    g_done_time_length = time() - g_start_time_time
    print('============================================================')
    print('============================================================')
    print('PROGRAM DONE : ', g_done_time)
    print('PROGRAM DONE IN {} seconds'.format(strftime("%H:%M:%S", gmtime(g_done_time_length))))

# %%
n_runs = 50

dir_info = True
directory = "50_by_100/"
file_prefix = "X_raw_disease_50_target_100_"
file_suffix = ".csv"

list_info = False
disease_ids = prediction_extended.efo_id.tolist()
target_ids = targets.ensembl_id.tolist()
n_diseases = 50
n_targets = 100

create_dataset(n_runs = n_runs,
               dir_info = dir_info,
               directory = directory,
               file_prefix = file_prefix,
               file_suffix = file_suffix,
               list_info = list_info,
               disease_ids = disease_ids,
               target_ids = target_ids,
               n_diseases = n_diseases,
               n_targets = n_targets)
# Out:
# PROGRAM START :  Sat May  9 23:30:40 2020
# ============================================================
# ============================================================
# Number of files in directory 50_by_100/ : 71
# /opt/anaconda3/lib/python3.7/site-packages/opentargets/conn.py:299: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.api_specs = yaml.load(self.swagger_yaml)
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:30:41 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 23.88 seconds.
# Time since last print : 23.88 seconds.
# -- 10  of  50
# Time : 64.47 seconds.
# Time since last print : 40.59 seconds.
# -- 15  of  50
# Time : 105.45 seconds.
# Time since last print : 40.98 seconds.
# -- 20  of  50
# Time : 136.61 seconds.
# Time since last print : 31.16 seconds.
# -- 25  of  50
# Time : 168.38 seconds.
# Time since last print : 31.77 seconds.
# -- 30  of  50
# Time : 196.89 seconds.
# Time since last print : 28.51 seconds.
# -- 35  of  50
# Time : 219.76 seconds.
# Time since last print : 22.87 seconds.
# -- 40  of  50
# Time : 247.26 seconds.
# Time since last print : 27.50 seconds.
# -- 45  of  50
# Time : 273.30 seconds.
# Time since last print : 26.04 seconds.
# -- 50  of  50
# Time : 300.57 seconds.
# Time since last print : 27.27 seconds.
# --------------------------------------------------
# BUILD End time :  Sat May  9 23:35:41 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 72
# ============================================================
# RUN STARTED :  Sat May  9 23:30:40 2020
# INIT DONE :    Sat May  9 23:30:40 2020
# RUN DONE :     Sat May  9 23:35:42 2020
# ============================================================
# Total execution time : 00:05:01
# ============================================================
# Number of files in directory 50_by_100/ : 72
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:35:43 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 29.03 seconds.
# Time since last print : 29.03 seconds.
# -- 10  of  50
# Time : 56.24 seconds.
# Time since last print : 27.21 seconds.
# -- 15  of  50
# Time : 84.97 seconds.
# Time since last print : 28.73 seconds.
# -- 20  of  50
# Time : 108.86 seconds.
# Time since last print : 23.89 seconds.
# -- 25  of  50
# Time : 139.43 seconds.
# Time since last print : 30.56 seconds.
# -- 30  of  50
# Time : 164.13 seconds.
# Time since last print : 24.71 seconds.
# -- 35  of  50
# Time : 187.29 seconds.
# Time since last print : 23.16 seconds.
# -- 40  of  50
# Time : 216.09 seconds.
# Time since last print : 28.80 seconds.
# -- 45  of  50
# Time : 243.83 seconds.
# Time since last print : 27.74 seconds.
# -- 50  of  50
# Time : 272.98 seconds.
# Time since last print : 29.15 seconds.
# --------------------------------------------------
# BUILD End time :  Sat May  9 23:40:16 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 73
# ============================================================
# RUN STARTED :  Sat May  9 23:35:42 2020
# INIT DONE :    Sat May  9 23:35:43 2020
# RUN DONE :     Sat May  9 23:40:17 2020
# ============================================================
# Total execution time : 00:04:34
# ============================================================
# Number of files in directory 50_by_100/ : 73
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:40:18 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 24.12 seconds.
# Time since last print : 24.12 seconds.
# -- 10  of  50
# Time : 42.78 seconds.
# Time since last print : 18.66 seconds.
# -- 15  of  50
# Time : 69.75 seconds.
# Time since last print : 26.97 seconds.
# -- 20  of  50
# Time : 96.51 seconds.
# Time since last print : 26.76 seconds.
# -- 25  of  50
# Time : 111.68 seconds.
# Time since last print : 15.17 seconds.
# -- 30  of  50
# Time : 140.18 seconds.
# Time since last print : 28.50 seconds.
# -- 35  of  50
# Time : 166.51 seconds.
# Time since last print : 26.33 seconds.
# -- 40  of  50
# Time : 193.78 seconds.
# Time since last print : 27.27 seconds.
# -- 45  of  50
# Time : 221.37 seconds.
# Time since last print : 27.59 seconds.
# -- 50  of  50
# Time : 248.24 seconds.
# Time since last print : 26.87 seconds.
# --------------------------------------------------
# BUILD End time :  Sat May  9 23:44:26 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 74
# ============================================================
# RUN STARTED :  Sat May  9 23:40:17 2020
# INIT DONE :    Sat May  9 23:40:18 2020
# RUN DONE :     Sat May  9 23:44:27 2020
# ============================================================
# Total execution time : 00:04:09
# ============================================================
# Number of files in directory 50_by_100/ : 74
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:44:28 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.14 seconds.
# Time since last print : 28.14 seconds.
# -- 10  of  50
# Time : 54.26 seconds.
# Time since last print : 26.11 seconds.
# -- 15  of  50
# Time : 78.52 seconds.
# Time since last print : 24.27 seconds.
# -- 20  of  50
# Time : 107.36 seconds.
# Time since last print : 28.84 seconds.
# -- 25  of  50
# Time : 134.70 seconds.
# Time since last print : 27.34 seconds.
# -- 30  of  50
# Time : 162.44 seconds.
# Time since last print : 27.74 seconds.
# -- 35  of  50
# Time : 190.04 seconds.
# Time since last print : 27.60 seconds.
# -- 40  of  50
# Time : 218.52 seconds.
# Time since last print : 28.48 seconds.
# -- 45  of  50
# Time : 246.26 seconds.
# Time since last print : 27.74 seconds.
# -- 50  of  50
# Time : 273.87 seconds.
# Time since last print : 27.61 seconds.
# --------------------------------------------------
# BUILD End time :  Sat May  9 23:49:02 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 75
# ============================================================
# RUN STARTED :  Sat May  9 23:44:27 2020
# INIT DONE :    Sat May  9 23:44:28 2020
# RUN DONE :     Sat May  9 23:49:03 2020
# ============================================================
# Total execution time : 00:04:35
# ============================================================
# Number of files in directory 50_by_100/ : 75
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:49:03 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.38 seconds.
# Time since last print : 28.38 seconds.
# -- 10  of  50
# Time : 56.06 seconds.
# Time since last print : 27.68 seconds.
# -- 15  of  50
# Time : 80.66 seconds.
# Time since last print : 24.60 seconds.
# -- 20  of  50
# Time : 107.77 seconds.
# Time since last print : 27.11 seconds.
# -- 25  of  50
# Time : 138.43 seconds.
# Time since last print : 30.66 seconds.
# -- 30  of  50
# Time : 163.26 seconds.
# Time since last print : 24.83 seconds.
# -- 35  of  50
# Time : 190.27 seconds.
# Time since last print : 27.01 seconds.
# -- 40  of  50
# Time : 214.78 seconds.
# Time since last print : 24.51 seconds.
# -- 45  of  50
# Time : 242.94 seconds.
# Time since last print : 28.15 seconds.
# -- 50  of  50
# Time : 271.42 seconds.
# Time since last print : 28.49 seconds.
# --------------------------------------------------
# BUILD End time :  Sat May  9 23:53:35 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 76
# ============================================================
# RUN STARTED :  Sat May  9 23:49:03 2020
# INIT DONE :    Sat May  9 23:49:03 2020
# RUN DONE :     Sat May  9 23:53:36 2020
# ============================================================
# Total execution time : 00:04:32
# ============================================================
# Number of files in directory 50_by_100/ : 76
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:53:37 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.86 seconds.
# Time since last print : 27.86 seconds.
# -- 10  of  50
# Time : 51.12 seconds.
# Time since last print : 23.26 seconds.
# -- 15  of  50
# Time : 78.75 seconds.
# Time since last print : 27.63 seconds.
# -- 20  of  50
# Time : 106.05 seconds.
# Time since last print : 27.31 seconds.
# -- 25  of  50
# Time : 131.44 seconds.
# Time since last print : 25.39 seconds.
# -- 30  of  50
# Time : 159.69 seconds.
# Time since last print : 28.25 seconds.
# -- 35  of  50
# Time : 187.97 seconds.
# Time since last print : 28.28 seconds.
# -- 40  of  50
# Time : 214.54 seconds.
# Time since last print : 26.57 seconds.
# -- 45  of  50
# Time : 237.75 seconds.
# Time since last print : 23.21 seconds.
# -- 50  of  50
# Time : 266.44 seconds.
# Time since last print : 28.69 seconds.
# --------------------------------------------------
# BUILD End time :  Sat May  9 23:58:03 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 77
# ============================================================
# RUN STARTED :  Sat May  9 23:53:36 2020
# INIT DONE :    Sat May  9 23:53:36 2020
# RUN DONE :     Sat May  9 23:58:04 2020
# ============================================================
# Total execution time : 00:04:27
# ============================================================
# Number of files in directory 50_by_100/ : 77
# --------------------------------------------------
# BUILD Start time :  Sat May  9 23:58:05 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.26 seconds.
# Time since last print : 27.26 seconds.
# -- 10  of  50
# Time : 54.98 seconds.
# Time since last print : 27.72 seconds.
# -- 15  of  50
# Time : 78.33 seconds.
# Time since last print : 23.35 seconds.
# -- 20  of  50
# Time : 101.91 seconds.
# Time since last print : 23.58 seconds.
# -- 25  of  50
# Time : 126.51 seconds.
# Time since last print : 24.60 seconds.
# -- 30  of  50
# Time : 154.00 seconds.
# Time since last print : 27.48 seconds.
# -- 35  of  50
# Time : 181.11 seconds.
# Time since last print : 27.11 seconds.
# -- 40  of  50
# Time : 206.76 seconds.
# Time since last print : 25.65 seconds.
# -- 45  of  50
# Time : 234.04 seconds.
# Time since last print : 27.28 seconds.
# -- 50  of  50
# Time : 261.13 seconds.
# Time since last print : 27.08 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:02:26 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 78
# ============================================================
# RUN STARTED :  Sat May  9 23:58:04 2020
# INIT DONE :    Sat May  9 23:58:05 2020
# RUN DONE :     Sun May 10 00:02:27 2020
# ============================================================
# Total execution time : 00:04:22
# ============================================================
# Number of files in directory 50_by_100/ : 78
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:02:28 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.71 seconds.
# Time since last print : 27.71 seconds.
# -- 10  of  50
# Time : 56.56 seconds.
# Time since last print : 28.84 seconds.
# -- 15  of  50
# Time : 85.80 seconds.
# Time since last print : 29.24 seconds.
# -- 20  of  50
# Time : 113.98 seconds.
# Time since last print : 28.18 seconds.
# -- 25  of  50
# Time : 143.38 seconds.
# Time since last print : 29.41 seconds.
# -- 30  of  50
# Time : 168.61 seconds.
# Time since last print : 25.22 seconds.
# -- 35  of  50
# Time : 196.36 seconds.
# Time since last print : 27.75 seconds.
# -- 40  of  50
# Time : 224.05 seconds.
# Time since last print : 27.69 seconds.
# -- 45  of  50
# Time : 253.57 seconds.
# Time since last print : 29.53 seconds.
# -- 50  of  50
# Time : 280.50 seconds.
# Time since last print : 26.93 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:07:08 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 79
# ============================================================
# RUN STARTED :  Sun May 10 00:02:27 2020
# INIT DONE :    Sun May 10 00:02:28 2020
# RUN DONE :     Sun May 10 00:07:09 2020
# ============================================================
# Total execution time : 00:04:41
# ============================================================
# Number of files in directory 50_by_100/ : 79
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:07:10 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 30.12 seconds.
# Time since last print : 30.12 seconds.
# -- 10  of  50
# Time : 57.54 seconds.
# Time since last print : 27.42 seconds.
# -- 15  of  50
# Time : 84.86 seconds.
# Time since last print : 27.32 seconds.
# -- 20  of  50
# Time : 110.95 seconds.
# Time since last print : 26.10 seconds.
# -- 25  of  50
# Time : 132.05 seconds.
# Time since last print : 21.10 seconds.
# -- 30  of  50
# Time : 160.17 seconds.
# Time since last print : 28.12 seconds.
# -- 35  of  50
# Time : 189.33 seconds.
# Time since last print : 29.16 seconds.
# -- 40  of  50
# Time : 216.32 seconds.
# Time since last print : 26.99 seconds.
# -- 45  of  50
# Time : 244.99 seconds.
# Time since last print : 28.67 seconds.
# -- 50  of  50
# Time : 273.33 seconds.
# Time since last print : 28.34 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:11:44 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 80
# ============================================================
# RUN STARTED :  Sun May 10 00:07:09 2020
# INIT DONE :    Sun May 10 00:07:10 2020
# RUN DONE :     Sun May 10 00:11:45 2020
# ============================================================
# Total execution time : 00:04:34
# ============================================================
# Number of files in directory 50_by_100/ : 80
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:11:46 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 29.08 seconds.
# Time since last print : 29.08 seconds.
# -- 10  of  50
# Time : 56.44 seconds.
# Time since last print : 27.36 seconds.
# -- 15  of  50
# Time : 84.94 seconds.
# Time since last print : 28.50 seconds.
# -- 20  of  50
# Time : 112.09 seconds.
# Time since last print : 27.15 seconds.
# -- 25  of  50
# Time : 140.50 seconds.
# Time since last print : 28.41 seconds.
# -- 30  of  50
# Time : 169.74 seconds.
# Time since last print : 29.23 seconds.
# -- 35  of  50
# Time : 196.43 seconds.
# Time since last print : 26.70 seconds.
# -- 40  of  50
# Time : 223.26 seconds.
# Time since last print : 26.83 seconds.
# -- 45  of  50
# Time : 250.89 seconds.
# Time since last print : 27.63 seconds.
# -- 50  of  50
# Time : 278.33 seconds.
# Time since last print : 27.43 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:16:24 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 81
# ============================================================
# RUN STARTED :  Sun May 10 00:11:45 2020
# INIT DONE :    Sun May 10 00:11:45 2020
# RUN DONE :     Sun May 10 00:16:25 2020
# ============================================================
# Total execution time : 00:04:39
# ============================================================
# Number of files in directory 50_by_100/ : 81
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:16:26 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.39 seconds.
# Time since last print : 27.39 seconds.
# -- 10  of  50
# Time : 54.92 seconds.
# Time since last print : 27.53 seconds.
# -- 15  of  50
# Time : 83.05 seconds.
# Time since last print : 28.13 seconds.
# -- 20  of  50
# Time : 110.88 seconds.
# Time since last print : 27.83 seconds.
# -- 25  of  50
# Time : 139.76 seconds.
# Time since last print : 28.88 seconds.
# -- 30  of  50
# Time : 159.37 seconds.
# Time since last print : 19.61 seconds.
# -- 35  of  50
# Time : 187.15 seconds.
# Time since last print : 27.77 seconds.
# -- 40  of  50
# Time : 215.83 seconds.
# Time since last print : 28.68 seconds.
# -- 45  of  50
# Time : 242.19 seconds.
# Time since last print : 26.36 seconds.
# -- 50  of  50
# Time : 271.11 seconds.
# Time since last print : 28.92 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:20:57 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 82
# ============================================================
# RUN STARTED :  Sun May 10 00:16:25 2020
# INIT DONE :    Sun May 10 00:16:26 2020
# RUN DONE :     Sun May 10 00:20:58 2020
# ============================================================
# Total execution time : 00:04:32
# ============================================================
# Number of files in directory 50_by_100/ : 82
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:20:59 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.16 seconds.
# Time since last print : 27.16 seconds.
# -- 10  of  50
# Time : 50.70 seconds.
# Time since last print : 23.54 seconds.
# -- 15  of  50
# Time : 78.74 seconds.
# Time since last print : 28.04 seconds.
# -- 20  of  50
# Time : 105.81 seconds.
# Time since last print : 27.07 seconds.
# -- 25  of  50
# Time : 129.08 seconds.
# Time since last print : 23.27 seconds.
# -- 30  of  50
# Time : 156.47 seconds.
# Time since last print : 27.39 seconds.
# -- 35  of  50
# Time : 180.38 seconds.
# Time since last print : 23.90 seconds.
# -- 40  of  50
# Time : 207.74 seconds.
# Time since last print : 27.36 seconds.
# -- 45  of  50
# Time : 235.06 seconds.
# Time since last print : 27.32 seconds.
# -- 50  of  50
# Time : 263.29 seconds.
# Time since last print : 28.23 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:25:22 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 83
# ============================================================
# RUN STARTED :  Sun May 10 00:20:58 2020
# INIT DONE :    Sun May 10 00:20:58 2020
# RUN DONE :     Sun May 10 00:25:23 2020
# ============================================================
# Total execution time : 00:04:24
# ============================================================
# Number of files in directory 50_by_100/ : 83
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:25:24 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.12 seconds.
# Time since last print : 27.12 seconds.
# -- 10  of  50
# Time : 54.42 seconds.
# Time since last print : 27.31 seconds.
# -- 15  of  50
# Time : 79.45 seconds.
# Time since last print : 25.03 seconds.
# -- 20  of  50
# Time : 106.85 seconds.
# Time since last print : 27.40 seconds.
# -- 25  of  50
# Time : 135.18 seconds.
# Time since last print : 28.33 seconds.
# -- 30  of  50
# Time : 162.44 seconds.
# Time since last print : 27.26 seconds.
# -- 35  of  50
# Time : 190.00 seconds.
# Time since last print : 27.56 seconds.
# -- 40  of  50
# Time : 217.07 seconds.
# Time since last print : 27.07 seconds.
# -- 45  of  50
# Time : 239.99 seconds.
# Time since last print : 22.92 seconds.
# -- 50  of  50
# Time : 268.08 seconds.
# Time since last print : 28.09 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:29:52 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 84
# ============================================================
# RUN STARTED :  Sun May 10 00:25:23 2020
# INIT DONE :    Sun May 10 00:25:23 2020
# RUN DONE :     Sun May 10 00:29:53 2020
# ============================================================
# Total execution time : 00:04:29
# ============================================================
# Number of files in directory 50_by_100/ : 84
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:29:53 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 22.63 seconds.
# Time since last print : 22.63 seconds.
# -- 10  of  50
# Time : 48.88 seconds.
# Time since last print : 26.25 seconds.
# -- 15  of  50
# Time : 76.13 seconds.
# Time since last print : 27.26 seconds.
# -- 20  of  50
# Time : 103.16 seconds.
# Time since last print : 27.03 seconds.
# -- 25  of  50
# Time : 131.65 seconds.
# Time since last print : 28.49 seconds.
# -- 30  of  50
# Time : 158.66 seconds.
# Time since last print : 27.02 seconds.
# -- 35  of  50
# Time : 184.51 seconds.
# Time since last print : 25.84 seconds.
# -- 40  of  50
# Time : 211.80 seconds.
# Time since last print : 27.29 seconds.
# -- 45  of  50
# Time : 238.47 seconds.
# Time since last print : 26.67 seconds.
# -- 50  of  50
# Time : 266.78 seconds.
# Time since last print : 28.31 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:34:20 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 85
# ============================================================
# RUN STARTED :  Sun May 10 00:29:53 2020
# INIT DONE :    Sun May 10 00:29:53 2020
# RUN DONE :     Sun May 10 00:34:21 2020
# ============================================================
# Total execution time : 00:04:27
# ============================================================
# Number of files in directory 50_by_100/ : 85
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:34:22 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 24.21 seconds.
# Time since last print : 24.21 seconds.
# -- 10  of  50
# Time : 52.15 seconds.
# Time since last print : 27.94 seconds.
# -- 15  of  50
# Time : 79.24 seconds.
# Time since last print : 27.09 seconds.
# -- 20  of  50
# Time : 104.34 seconds.
# Time since last print : 25.10 seconds.
# -- 25  of  50
# Time : 131.01 seconds.
# Time since last print : 26.67 seconds.
# -- 30  of  50
# Time : 158.11 seconds.
# Time since last print : 27.10 seconds.
# -- 35  of  50
# Time : 187.14 seconds.
# Time since last print : 29.02 seconds.
# -- 40  of  50
# Time : 214.28 seconds.
# Time since last print : 27.14 seconds.
# -- 45  of  50
# Time : 238.19 seconds.
# Time since last print : 23.91 seconds.
# -- 50  of  50
# Time : 265.10 seconds.
# Time since last print : 26.91 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:38:47 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 86
# ============================================================
# RUN STARTED :  Sun May 10 00:34:21 2020
# INIT DONE :    Sun May 10 00:34:22 2020
# RUN DONE :     Sun May 10 00:38:48 2020
# ============================================================
# Total execution time : 00:04:26
# ============================================================
# Number of files in directory 50_by_100/ : 86
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:38:49 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 26.93 seconds.
# Time since last print : 26.93 seconds.
# -- 10  of  50
# Time : 55.58 seconds.
# Time since last print : 28.65 seconds.
# -- 15  of  50
# Time : 82.61 seconds.
# Time since last print : 27.03 seconds.
# -- 20  of  50
# Time : 111.00 seconds.
# Time since last print : 28.39 seconds.
# -- 25  of  50
# Time : 139.36 seconds.
# Time since last print : 28.36 seconds.
# -- 30  of  50
# Time : 167.35 seconds.
# Time since last print : 27.99 seconds.
# -- 35  of  50
# Time : 194.51 seconds.
# Time since last print : 27.16 seconds.
# -- 40  of  50
# Time : 218.63 seconds.
# Time since last print : 24.13 seconds.
# -- 45  of  50
# Time : 242.80 seconds.
# Time since last print : 24.16 seconds.
# -- 50  of  50
# Time : 266.00 seconds.
# Time since last print : 23.20 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:43:15 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 87
# ============================================================
# RUN STARTED :  Sun May 10 00:38:48 2020
# INIT DONE :    Sun May 10 00:38:49 2020
# RUN DONE :     Sun May 10 00:43:16 2020
# ============================================================
# Total execution time : 00:04:27
# ============================================================
# Number of files in directory 50_by_100/ : 87
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:43:17 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 22.74 seconds.
# Time since last print : 22.74 seconds.
# -- 10  of  50
# Time : 51.00 seconds.
# Time since last print : 28.25 seconds.
# -- 15  of  50
# Time : 77.93 seconds.
# Time since last print : 26.93 seconds.
# -- 20  of  50
# Time : 101.84 seconds.
# Time since last print : 23.91 seconds.
# -- 25  of  50
# Time : 129.28 seconds.
# Time since last print : 27.44 seconds.
# -- 30  of  50
# Time : 156.52 seconds.
# Time since last print : 27.24 seconds.
# -- 35  of  50
# Time : 181.09 seconds.
# Time since last print : 24.57 seconds.
# -- 40  of  50
# Time : 204.68 seconds.
# Time since last print : 23.60 seconds.
# -- 45  of  50
# Time : 233.58 seconds.
# Time since last print : 28.90 seconds.
# -- 50  of  50
# Time : 260.51 seconds.
# Time since last print : 26.92 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:47:37 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 88
# ============================================================
# RUN STARTED :  Sun May 10 00:43:16 2020
# INIT DONE :    Sun May 10 00:43:17 2020
# RUN DONE :     Sun May 10 00:47:38 2020
# ============================================================
# Total execution time : 00:04:21
# ============================================================
# Number of files in directory 50_by_100/ : 88
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:47:39 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.42 seconds.
# Time since last print : 27.42 seconds.
# -- 10  of  50
# Time : 56.79 seconds.
# Time since last print : 29.37 seconds.
# -- 15  of  50
# Time : 80.97 seconds.
# Time since last print : 24.18 seconds.
# -- 20  of  50
# Time : 110.19 seconds.
# Time since last print : 29.22 seconds.
# -- 25  of  50
# Time : 133.66 seconds.
# Time since last print : 23.47 seconds.
# -- 30  of  50
# Time : 161.53 seconds.
# Time since last print : 27.88 seconds.
# -- 35  of  50
# Time : 190.36 seconds.
# Time since last print : 28.83 seconds.
# -- 40  of  50
# Time : 218.04 seconds.
# Time since last print : 27.67 seconds.
# -- 45  of  50
# Time : 247.85 seconds.
# Time since last print : 29.81 seconds.
# -- 50  of  50
# Time : 276.93 seconds.
# Time since last print : 29.08 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:52:16 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 89
# ============================================================
# RUN STARTED :  Sun May 10 00:47:38 2020
# INIT DONE :    Sun May 10 00:47:39 2020
# RUN DONE :     Sun May 10 00:52:17 2020
# ============================================================
# Total execution time : 00:04:38
# ============================================================
# Number of files in directory 50_by_100/ : 89
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:52:18 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.81 seconds.
# Time since last print : 28.81 seconds.
# -- 10  of  50
# Time : 57.06 seconds.
# Time since last print : 28.25 seconds.
# -- 15  of  50
# Time : 86.76 seconds.
# Time since last print : 29.70 seconds.
# -- 20  of  50
# Time : 114.93 seconds.
# Time since last print : 28.18 seconds.
# -- 25  of  50
# Time : 140.85 seconds.
# Time since last print : 25.92 seconds.
# -- 30  of  50
# Time : 173.44 seconds.
# Time since last print : 32.59 seconds.
# -- 35  of  50
# Time : 197.05 seconds.
# Time since last print : 23.61 seconds.
# -- 40  of  50
# Time : 221.89 seconds.
# Time since last print : 24.84 seconds.
# -- 45  of  50
# Time : 250.10 seconds.
# Time since last print : 28.21 seconds.
# -- 50  of  50
# Time : 278.09 seconds.
# Time since last print : 27.99 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 00:56:56 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 90
# ============================================================
# RUN STARTED :  Sun May 10 00:52:17 2020
# INIT DONE :    Sun May 10 00:52:18 2020
# RUN DONE :     Sun May 10 00:56:57 2020
# ============================================================
# Total execution time : 00:04:39
# ============================================================
# Number of files in directory 50_by_100/ : 90
# --------------------------------------------------
# BUILD Start time :  Sun May 10 00:56:58 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.41 seconds.
# Time since last print : 28.41 seconds.
# -- 10  of  50
# Time : 55.12 seconds.
# Time since last print : 26.71 seconds.
# -- 15  of  50
# Time : 79.68 seconds.
# Time since last print : 24.55 seconds.
# -- 20  of  50
# Time : 106.52 seconds.
# Time since last print : 26.84 seconds.
# -- 25  of  50
# Time : 134.14 seconds.
# Time since last print : 27.62 seconds.
# -- 30  of  50
# Time : 162.63 seconds.
# Time since last print : 28.49 seconds.
# -- 35  of  50
# Time : 186.18 seconds.
# Time since last print : 23.55 seconds.
# -- 40  of  50
# Time : 215.70 seconds.
# Time since last print : 29.52 seconds.
# -- 45  of  50
# Time : 242.75 seconds.
# Time since last print : 27.05 seconds.
# -- 50  of  50
# Time : 267.59 seconds.
# Time since last print : 24.84 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:01:25 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 91
# ============================================================
# RUN STARTED :  Sun May 10 00:56:57 2020
# INIT DONE :    Sun May 10 00:56:57 2020
# RUN DONE :     Sun May 10 01:01:26 2020
# ============================================================
# Total execution time : 00:04:28
# ============================================================
# Number of files in directory 50_by_100/ : 91
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:01:27 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.58 seconds.
# Time since last print : 27.58 seconds.
# -- 10  of  50
# Time : 51.21 seconds.
# Time since last print : 23.63 seconds.
# -- 15  of  50
# Time : 79.85 seconds.
# Time since last print : 28.64 seconds.
# -- 20  of  50
# Time : 102.96 seconds.
# Time since last print : 23.10 seconds.
# -- 25  of  50
# Time : 126.13 seconds.
# Time since last print : 23.17 seconds.
# -- 30  of  50
# Time : 155.29 seconds.
# Time since last print : 29.16 seconds.
# -- 35  of  50
# Time : 182.29 seconds.
# Time since last print : 27.00 seconds.
# -- 40  of  50
# Time : 209.71 seconds.
# Time since last print : 27.43 seconds.
# -- 45  of  50
# Time : 232.96 seconds.
# Time since last print : 23.25 seconds.
# -- 50  of  50
# Time : 261.05 seconds.
# Time since last print : 28.09 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:05:48 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 92
# ============================================================
# RUN STARTED :  Sun May 10 01:01:26 2020
# INIT DONE :    Sun May 10 01:01:27 2020
# RUN DONE :     Sun May 10 01:05:49 2020
# ============================================================
# Total execution time : 00:04:22
# ============================================================
# Number of files in directory 50_by_100/ : 92
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:05:50 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.47 seconds.
# Time since last print : 27.47 seconds.
# -- 10  of  50
# Time : 51.22 seconds.
# Time since last print : 23.75 seconds.
# -- 15  of  50
# Time : 80.01 seconds.
# Time since last print : 28.80 seconds.
# -- 20  of  50
# Time : 107.80 seconds.
# Time since last print : 27.79 seconds.
# -- 25  of  50
# Time : 139.01 seconds.
# Time since last print : 31.21 seconds.
# -- 30  of  50
# Time : 166.57 seconds.
# Time since last print : 27.57 seconds.
# -- 35  of  50
# Time : 195.38 seconds.
# Time since last print : 28.81 seconds.
# -- 40  of  50
# Time : 218.46 seconds.
# Time since last print : 23.08 seconds.
# -- 45  of  50
# Time : 245.57 seconds.
# Time since last print : 27.11 seconds.
# -- 50  of  50
# Time : 274.00 seconds.
# Time since last print : 28.43 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:10:24 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 93
# ============================================================
# RUN STARTED :  Sun May 10 01:05:49 2020
# INIT DONE :    Sun May 10 01:05:50 2020
# RUN DONE :     Sun May 10 01:10:25 2020
# ============================================================
# Total execution time : 00:04:35
# ============================================================
# Number of files in directory 50_by_100/ : 93
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:10:26 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 22.93 seconds.
# Time since last print : 22.93 seconds.
# -- 10  of  50
# Time : 51.33 seconds.
# Time since last print : 28.41 seconds.
# -- 15  of  50
# Time : 77.66 seconds.
# Time since last print : 26.33 seconds.
# -- 20  of  50
# Time : 102.19 seconds.
# Time since last print : 24.53 seconds.
# -- 25  of  50
# Time : 130.99 seconds.
# Time since last print : 28.80 seconds.
# -- 30  of  50
# Time : 158.55 seconds.
# Time since last print : 27.56 seconds.
# -- 35  of  50
# Time : 186.13 seconds.
# Time since last print : 27.58 seconds.
# -- 40  of  50
# Time : 212.96 seconds.
# Time since last print : 26.83 seconds.
# -- 45  of  50
# Time : 240.31 seconds.
# Time since last print : 27.34 seconds.
# -- 50  of  50
# Time : 268.58 seconds.
# Time since last print : 28.27 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:14:55 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 94
# ============================================================
# RUN STARTED :  Sun May 10 01:10:25 2020
# INIT DONE :    Sun May 10 01:10:26 2020
# RUN DONE :     Sun May 10 01:14:56 2020
# ============================================================
# Total execution time : 00:04:29
# ============================================================
# Number of files in directory 50_by_100/ : 94
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:14:57 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 23.07 seconds.
# Time since last print : 23.07 seconds.
# -- 10  of  50
# Time : 51.71 seconds.
# Time since last print : 28.64 seconds.
# -- 15  of  50
# Time : 78.28 seconds.
# Time since last print : 26.58 seconds.
# -- 20  of  50
# Time : 101.37 seconds.
# Time since last print : 23.09 seconds.
# -- 25  of  50
# Time : 127.98 seconds.
# Time since last print : 26.61 seconds.
# -- 30  of  50
# Time : 155.42 seconds.
# Time since last print : 27.44 seconds.
# -- 35  of  50
# Time : 183.19 seconds.
# Time since last print : 27.77 seconds.
# -- 40  of  50
# Time : 209.91 seconds.
# Time since last print : 26.72 seconds.
# -- 45  of  50
# Time : 237.49 seconds.
# Time since last print : 27.58 seconds.
# -- 50  of  50
# Time : 265.07 seconds.
# Time since last print : 27.59 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:19:22 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 95
# ============================================================
# RUN STARTED :  Sun May 10 01:14:56 2020
# INIT DONE :    Sun May 10 01:14:57 2020
# RUN DONE :     Sun May 10 01:19:23 2020
# ============================================================
# Total execution time : 00:04:26
# ============================================================
# Number of files in directory 50_by_100/ : 95
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:19:24 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.04 seconds.
# Time since last print : 27.04 seconds.
# -- 10  of  50
# Time : 55.13 seconds.
# Time since last print : 28.09 seconds.
# -- 15  of  50
# Time : 82.31 seconds.
# Time since last print : 27.18 seconds.
# -- 20  of  50
# Time : 107.29 seconds.
# Time since last print : 24.97 seconds.
# -- 25  of  50
# Time : 134.87 seconds.
# Time since last print : 27.58 seconds.
# -- 30  of  50
# Time : 162.47 seconds.
# Time since last print : 27.61 seconds.
# -- 35  of  50
# Time : 190.80 seconds.
# Time since last print : 28.32 seconds.
# -- 40  of  50
# Time : 217.67 seconds.
# Time since last print : 26.87 seconds.
# -- 45  of  50
# Time : 245.98 seconds.
# Time since last print : 28.31 seconds.
# -- 50  of  50
# Time : 273.48 seconds.
# Time since last print : 27.50 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:23:57 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 96
# ============================================================
# RUN STARTED :  Sun May 10 01:19:23 2020
# INIT DONE :    Sun May 10 01:19:24 2020
# RUN DONE :     Sun May 10 01:23:59 2020
# ============================================================
# Total execution time : 00:04:34
# ============================================================
# Number of files in directory 50_by_100/ : 96
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:24:00 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 23.07 seconds.
# Time since last print : 23.07 seconds.
# -- 10  of  50
# Time : 50.85 seconds.
# Time since last print : 27.77 seconds.
# -- 15  of  50
# Time : 73.31 seconds.
# Time since last print : 22.47 seconds.
# -- 20  of  50
# Time : 98.27 seconds.
# Time since last print : 24.96 seconds.
# -- 25  of  50
# Time : 125.54 seconds.
# Time since last print : 27.26 seconds.
# -- 30  of  50
# Time : 153.37 seconds.
# Time since last print : 27.83 seconds.
# -- 35  of  50
# Time : 181.33 seconds.
# Time since last print : 27.97 seconds.
# -- 40  of  50
# Time : 208.47 seconds.
# Time since last print : 27.14 seconds.
# -- 45  of  50
# Time : 235.27 seconds.
# Time since last print : 26.80 seconds.
# -- 50  of  50
# Time : 262.50 seconds.
# Time since last print : 27.23 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:28:22 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 97
# ============================================================
# RUN STARTED :  Sun May 10 01:23:59 2020
# INIT DONE :    Sun May 10 01:23:59 2020
# RUN DONE :     Sun May 10 01:28:23 2020
# ============================================================
# Total execution time : 00:04:23
# ============================================================
# Number of files in directory 50_by_100/ : 97
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:28:24 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 15.75 seconds.
# Time since last print : 15.75 seconds.
# -- 10  of  50
# Time : 45.20 seconds.
# Time since last print : 29.45 seconds.
# -- 15  of  50
# Time : 68.71 seconds.
# Time since last print : 23.51 seconds.
# -- 20  of  50
# Time : 97.22 seconds.
# Time since last print : 28.51 seconds.
# -- 25  of  50
# Time : 121.11 seconds.
# Time since last print : 23.89 seconds.
# -- 30  of  50
# Time : 148.78 seconds.
# Time since last print : 27.67 seconds.
# -- 35  of  50
# Time : 176.86 seconds.
# Time since last print : 28.08 seconds.
# -- 40  of  50
# Time : 203.68 seconds.
# Time since last print : 26.82 seconds.
# -- 45  of  50
# Time : 233.87 seconds.
# Time since last print : 30.19 seconds.
# -- 50  of  50
# Time : 260.56 seconds.
# Time since last print : 26.69 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:32:45 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 98
# ============================================================
# RUN STARTED :  Sun May 10 01:28:23 2020
# INIT DONE :    Sun May 10 01:28:24 2020
# RUN DONE :     Sun May 10 01:32:46 2020
# ============================================================
# Total execution time : 00:04:22
# ============================================================
# Number of files in directory 50_by_100/ : 98
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:32:47 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.81 seconds.
# Time since last print : 27.81 seconds.
# -- 10  of  50
# Time : 54.54 seconds.
# Time since last print : 26.73 seconds.
# -- 15  of  50
# Time : 81.67 seconds.
# Time since last print : 27.13 seconds.
# -- 20  of  50
# Time : 110.18 seconds.
# Time since last print : 28.51 seconds.
# -- 25  of  50
# Time : 137.28 seconds.
# Time since last print : 27.10 seconds.
# -- 30  of  50
# Time : 161.43 seconds.
# Time since last print : 24.15 seconds.
# -- 35  of  50
# Time : 188.64 seconds.
# Time since last print : 27.21 seconds.
# -- 40  of  50
# Time : 215.38 seconds.
# Time since last print : 26.74 seconds.
# -- 45  of  50
# Time : 243.55 seconds.
# Time since last print : 28.17 seconds.
# -- 50  of  50
# Time : 270.75 seconds.
# Time since last print : 27.20 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:37:18 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 99
# ============================================================
# RUN STARTED :  Sun May 10 01:32:46 2020
# INIT DONE :    Sun May 10 01:32:47 2020
# RUN DONE :     Sun May 10 01:37:19 2020
# ============================================================
# Total execution time : 00:04:32
# ============================================================
# Number of files in directory 50_by_100/ : 99
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:37:20 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 18.89 seconds.
# Time since last print : 18.89 seconds.
# -- 10  of  50
# Time : 45.31 seconds.
# Time since last print : 26.42 seconds.
# -- 15  of  50
# Time : 67.95 seconds.
# Time since last print : 22.64 seconds.
# -- 20  of  50
# Time : 96.13 seconds.
# Time since last print : 28.18 seconds.
# -- 25  of  50
# Time : 123.49 seconds.
# Time since last print : 27.37 seconds.
# -- 30  of  50
# Time : 152.01 seconds.
# Time since last print : 28.51 seconds.
# -- 35  of  50
# Time : 178.87 seconds.
# Time since last print : 26.86 seconds.
# -- 40  of  50
# Time : 205.36 seconds.
# Time since last print : 26.49 seconds.
# -- 45  of  50
# Time : 233.93 seconds.
# Time since last print : 28.57 seconds.
# -- 50  of  50
# Time : 260.74 seconds.
# Time since last print : 26.81 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:41:41 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 100
# ============================================================
# RUN STARTED :  Sun May 10 01:37:19 2020
# INIT DONE :    Sun May 10 01:37:20 2020
# RUN DONE :     Sun May 10 01:41:42 2020
# ============================================================
# Total execution time : 00:04:22
# ============================================================
# Number of files in directory 50_by_100/ : 100
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:41:43 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 24.54 seconds.
# Time since last print : 24.54 seconds.
# -- 10  of  50
# Time : 52.31 seconds.
# Time since last print : 27.77 seconds.
# -- 15  of  50
# Time : 76.26 seconds.
# Time since last print : 23.95 seconds.
# -- 20  of  50
# Time : 101.49 seconds.
# Time since last print : 25.23 seconds.
# -- 25  of  50
# Time : 124.90 seconds.
# Time since last print : 23.41 seconds.
# -- 30  of  50
# Time : 155.55 seconds.
# Time since last print : 30.65 seconds.
# -- 35  of  50
# Time : 183.29 seconds.
# Time since last print : 27.73 seconds.
# -- 40  of  50
# Time : 211.81 seconds.
# Time since last print : 28.52 seconds.
# -- 45  of  50
# Time : 238.30 seconds.
# Time since last print : 26.49 seconds.
# -- 50  of  50
# Time : 265.05 seconds.
# Time since last print : 26.76 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:46:08 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 101
# ============================================================
# RUN STARTED :  Sun May 10 01:41:42 2020
# INIT DONE :    Sun May 10 01:41:43 2020
# RUN DONE :     Sun May 10 01:46:09 2020
# ============================================================
# Total execution time : 00:04:26
# ============================================================
# Number of files in directory 50_by_100/ : 101
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:46:10 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.32 seconds.
# Time since last print : 28.32 seconds.
# -- 10  of  50
# Time : 51.73 seconds.
# Time since last print : 23.41 seconds.
# -- 15  of  50
# Time : 81.47 seconds.
# Time since last print : 29.75 seconds.
# -- 20  of  50
# Time : 108.64 seconds.
# Time since last print : 27.17 seconds.
# -- 25  of  50
# Time : 132.30 seconds.
# Time since last print : 23.66 seconds.
# -- 30  of  50
# Time : 161.46 seconds.
# Time since last print : 29.16 seconds.
# -- 35  of  50
# Time : 185.05 seconds.
# Time since last print : 23.59 seconds.
# -- 40  of  50
# Time : 212.47 seconds.
# Time since last print : 27.43 seconds.
# -- 45  of  50
# Time : 239.75 seconds.
# Time since last print : 27.28 seconds.
# -- 50  of  50
# Time : 267.38 seconds.
# Time since last print : 27.63 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:50:38 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 102
# ============================================================
# RUN STARTED :  Sun May 10 01:46:09 2020
# INIT DONE :    Sun May 10 01:46:10 2020
# RUN DONE :     Sun May 10 01:50:39 2020
# ============================================================
# Total execution time : 00:04:28
# ============================================================
# Number of files in directory 50_by_100/ : 102
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:50:40 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 19.08 seconds.
# Time since last print : 19.08 seconds.
# -- 10  of  50
# Time : 42.24 seconds.
# Time since last print : 23.17 seconds.
# -- 15  of  50
# Time : 71.63 seconds.
# Time since last print : 29.39 seconds.
# -- 20  of  50
# Time : 94.90 seconds.
# Time since last print : 23.27 seconds.
# -- 25  of  50
# Time : 118.26 seconds.
# Time since last print : 23.36 seconds.
# -- 30  of  50
# Time : 142.79 seconds.
# Time since last print : 24.53 seconds.
# -- 35  of  50
# Time : 170.31 seconds.
# Time since last print : 27.52 seconds.
# -- 40  of  50
# Time : 198.89 seconds.
# Time since last print : 28.58 seconds.
# -- 45  of  50
# Time : 226.36 seconds.
# Time since last print : 27.47 seconds.
# -- 50  of  50
# Time : 254.02 seconds.
# Time since last print : 27.66 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 01:54:54 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 103
# ============================================================
# RUN STARTED :  Sun May 10 01:50:39 2020
# INIT DONE :    Sun May 10 01:50:40 2020
# RUN DONE :     Sun May 10 01:54:55 2020
# ============================================================
# Total execution time : 00:04:15
# ============================================================
# Number of files in directory 50_by_100/ : 103
# --------------------------------------------------
# BUILD Start time :  Sun May 10 01:54:56 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.07 seconds.
# Time since last print : 28.07 seconds.
# -- 10  of  50
# Time : 52.10 seconds.
# Time since last print : 24.04 seconds.
# -- 15  of  50
# Time : 80.96 seconds.
# Time since last print : 28.86 seconds.
# ...
# Time : 104.86 seconds.
# Time since last print : 24.67 seconds.
# -- 25  of  50
# Time : 132.12 seconds.
# Time since last print : 27.27 seconds.
# -- 30  of  50
# Time : 160.51 seconds.
# Time since last print : 28.39 seconds.
# -- 35  of  50
# Time : 187.08 seconds.
# Time since last print : 26.56 seconds.
# -- 40  of  50
# Time : 214.06 seconds.
# Time since last print : 26.99 seconds.
# -- 45  of  50
# Time : 242.54 seconds.
# Time since last print : 28.48 seconds.
# -- 50  of  50
# Time : 269.78 seconds.
# Time since last print : 27.24 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:29:47 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 111
# ============================================================
# RUN STARTED :  Sun May 10 02:25:16 2020
# INIT DONE :    Sun May 10 02:25:17 2020
# RUN DONE :     Sun May 10 02:29:48 2020
# ============================================================
# Total execution time : 00:04:31
# ============================================================
# Number of files in directory 50_by_100/ : 111
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:29:49 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 27.90 seconds.
# Time since last print : 27.90 seconds.
# -- 10  of  50
# Time : 56.43 seconds.
# Time since last print : 28.53 seconds.
# -- 15  of  50
# Time : 79.33 seconds.
# Time since last print : 22.90 seconds.
# -- 20  of  50
# Time : 103.58 seconds.
# Time since last print : 24.24 seconds.
# -- 25  of  50
# Time : 127.21 seconds.
# Time since last print : 23.63 seconds.
# -- 30  of  50
# Time : 155.86 seconds.
# Time since last print : 28.65 seconds.
# -- 35  of  50
# Time : 183.36 seconds.
# Time since last print : 27.49 seconds.
# -- 40  of  50
# Time : 206.43 seconds.
# Time since last print : 23.07 seconds.
# -- 45  of  50
# Time : 229.70 seconds.
# Time since last print : 23.27 seconds.
# -- 50  of  50
# Time : 255.85 seconds.
# Time since last print : 26.15 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:34:05 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 112
# ============================================================
# RUN STARTED :  Sun May 10 02:29:48 2020
# INIT DONE :    Sun May 10 02:29:49 2020
# RUN DONE :     Sun May 10 02:34:06 2020
# ============================================================
# Total execution time : 00:04:17
# ============================================================
# Number of files in directory 50_by_100/ : 112
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:34:07 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.12 seconds.
# Time since last print : 28.12 seconds.
# -- 10  of  50
# Time : 54.79 seconds.
# Time since last print : 26.67 seconds.
# -- 15  of  50
# Time : 81.63 seconds.
# Time since last print : 26.85 seconds.
# -- 20  of  50
# Time : 110.32 seconds.
# Time since last print : 28.68 seconds.
# -- 25  of  50
# Time : 138.02 seconds.
# Time since last print : 27.70 seconds.
# -- 30  of  50
# Time : 166.96 seconds.
# Time since last print : 28.94 seconds.
# -- 35  of  50
# Time : 193.51 seconds.
# Time since last print : 26.54 seconds.
# -- 40  of  50
# Time : 220.62 seconds.
# Time since last print : 27.12 seconds.
# -- 45  of  50
# Time : 247.85 seconds.
# Time since last print : 27.23 seconds.
# -- 50  of  50
# Time : 275.15 seconds.
# Time since last print : 27.30 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:38:42 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 113
# ============================================================
# RUN STARTED :  Sun May 10 02:34:06 2020
# INIT DONE :    Sun May 10 02:34:07 2020
# RUN DONE :     Sun May 10 02:38:43 2020
# ============================================================
# Total execution time : 00:04:36
# ============================================================
# Number of files in directory 50_by_100/ : 113
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:38:44 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.30 seconds.
# Time since last print : 28.30 seconds.
# -- 10  of  50
# Time : 51.83 seconds.
# Time since last print : 23.52 seconds.
# -- 15  of  50
# Time : 76.61 seconds.
# Time since last print : 24.79 seconds.
# -- 20  of  50
# Time : 104.20 seconds.
# Time since last print : 27.58 seconds.
# -- 25  of  50
# Time : 127.70 seconds.
# Time since last print : 23.50 seconds.
# -- 30  of  50
# Time : 156.19 seconds.
# Time since last print : 28.49 seconds.
# -- 35  of  50
# Time : 179.50 seconds.
# Time since last print : 23.30 seconds.
# -- 40  of  50
# Time : 206.85 seconds.
# Time since last print : 27.36 seconds.
# -- 45  of  50
# Time : 234.12 seconds.
# Time since last print : 27.26 seconds.
# -- 50  of  50
# Time : 262.01 seconds.
# Time since last print : 27.89 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:43:06 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 114
# ============================================================
# RUN STARTED :  Sun May 10 02:38:43 2020
# INIT DONE :    Sun May 10 02:38:44 2020
# RUN DONE :     Sun May 10 02:43:08 2020
# ============================================================
# Total execution time : 00:04:23
# ============================================================
# Number of files in directory 50_by_100/ : 114
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:43:09 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.25 seconds.
# Time since last print : 28.25 seconds.
# -- 10  of  50
# Time : 55.81 seconds.
# Time since last print : 27.55 seconds.
# -- 15  of  50
# Time : 79.35 seconds.
# Time since last print : 23.54 seconds.
# -- 20  of  50
# Time : 102.89 seconds.
# Time since last print : 23.54 seconds.
# -- 25  of  50
# Time : 129.96 seconds.
# Time since last print : 27.07 seconds.
# -- 30  of  50
# Time : 158.82 seconds.
# Time since last print : 28.86 seconds.
# -- 35  of  50
# Time : 186.22 seconds.
# Time since last print : 27.40 seconds.
# -- 40  of  50
# Time : 215.14 seconds.
# Time since last print : 28.92 seconds.
# -- 45  of  50
# Time : 239.02 seconds.
# Time since last print : 23.88 seconds.
# -- 50  of  50
# Time : 267.99 seconds.
# Time since last print : 28.97 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:47:37 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 115
# ============================================================
# RUN STARTED :  Sun May 10 02:43:08 2020
# INIT DONE :    Sun May 10 02:43:09 2020
# RUN DONE :     Sun May 10 02:47:38 2020
# ============================================================
# Total execution time : 00:04:29
# ============================================================
# Number of files in directory 50_by_100/ : 115
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:47:39 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 26.94 seconds.
# Time since last print : 26.94 seconds.
# -- 10  of  50
# Time : 53.71 seconds.
# Time since last print : 26.77 seconds.
# -- 15  of  50
# Time : 77.60 seconds.
# Time since last print : 23.89 seconds.
# -- 20  of  50
# Time : 105.00 seconds.
# Time since last print : 27.40 seconds.
# -- 25  of  50
# Time : 133.65 seconds.
# Time since last print : 28.65 seconds.
# -- 30  of  50
# Time : 160.84 seconds.
# Time since last print : 27.19 seconds.
# -- 35  of  50
# Time : 183.73 seconds.
# Time since last print : 22.89 seconds.
# -- 40  of  50
# Time : 211.37 seconds.
# Time since last print : 27.64 seconds.
# -- 45  of  50
# Time : 238.33 seconds.
# Time since last print : 26.95 seconds.
# -- 50  of  50
# Time : 267.17 seconds.
# Time since last print : 28.84 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:52:06 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 116
# ============================================================
# RUN STARTED :  Sun May 10 02:47:38 2020
# INIT DONE :    Sun May 10 02:47:39 2020
# RUN DONE :     Sun May 10 02:52:08 2020
# ============================================================
# Total execution time : 00:04:28
# ============================================================
# Number of files in directory 50_by_100/ : 116
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:52:09 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 24.47 seconds.
# Time since last print : 24.47 seconds.
# -- 10  of  50
# Time : 44.95 seconds.
# Time since last print : 20.48 seconds.
# -- 15  of  50
# Time : 70.17 seconds.
# Time since last print : 25.22 seconds.
# -- 20  of  50
# Time : 97.28 seconds.
# Time since last print : 27.11 seconds.
# -- 25  of  50
# Time : 126.15 seconds.
# Time since last print : 28.87 seconds.
# -- 30  of  50
# Time : 152.98 seconds.
# Time since last print : 26.83 seconds.
# -- 35  of  50
# Time : 176.71 seconds.
# Time since last print : 23.73 seconds.
# -- 40  of  50
# Time : 205.49 seconds.
# Time since last print : 28.78 seconds.
# -- 45  of  50
# Time : 228.76 seconds.
# Time since last print : 23.26 seconds.
# -- 50  of  50
# Time : 257.59 seconds.
# Time since last print : 28.83 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 02:56:26 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 117
# ============================================================
# RUN STARTED :  Sun May 10 02:52:08 2020
# INIT DONE :    Sun May 10 02:52:09 2020
# RUN DONE :     Sun May 10 02:56:28 2020
# ============================================================
# Total execution time : 00:04:19
# ============================================================
# Number of files in directory 50_by_100/ : 117
# --------------------------------------------------
# BUILD Start time :  Sun May 10 02:56:29 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 18.52 seconds.
# Time since last print : 18.52 seconds.
# -- 10  of  50
# Time : 45.38 seconds.
# Time since last print : 26.86 seconds.
# -- 15  of  50
# Time : 76.16 seconds.
# Time since last print : 30.78 seconds.
# -- 20  of  50
# Time : 103.51 seconds.
# Time since last print : 27.35 seconds.
# -- 25  of  50
# Time : 131.06 seconds.
# Time since last print : 27.55 seconds.
# -- 30  of  50
# Time : 157.54 seconds.
# Time since last print : 26.48 seconds.
# -- 35  of  50
# Time : 186.75 seconds.
# Time since last print : 29.20 seconds.
# -- 40  of  50
# Time : 214.42 seconds.
# Time since last print : 27.68 seconds.
# -- 45  of  50
# Time : 238.46 seconds.
# Time since last print : 24.04 seconds.
# -- 50  of  50
# Time : 266.30 seconds.
# Time since last print : 27.84 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 03:00:55 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 118
# ============================================================
# RUN STARTED :  Sun May 10 02:56:28 2020
# INIT DONE :    Sun May 10 02:56:29 2020
# RUN DONE :     Sun May 10 03:00:57 2020
# ============================================================
# Total execution time : 00:04:28
# ============================================================
# Number of files in directory 50_by_100/ : 118
# --------------------------------------------------
# BUILD Start time :  Sun May 10 03:00:58 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 22.69 seconds.
# Time since last print : 22.69 seconds.
# -- 10  of  50
# Time : 46.31 seconds.
# Time since last print : 23.61 seconds.
# -- 15  of  50
# Time : 70.71 seconds.
# Time since last print : 24.40 seconds.
# -- 20  of  50
# Time : 90.20 seconds.
# Time since last print : 19.49 seconds.
# -- 25  of  50
# Time : 113.29 seconds.
# Time since last print : 23.09 seconds.
# -- 30  of  50
# Time : 137.97 seconds.
# Time since last print : 24.68 seconds.
# -- 35  of  50
# Time : 163.28 seconds.
# Time since last print : 25.31 seconds.
# -- 40  of  50
# Time : 187.62 seconds.
# Time since last print : 24.34 seconds.
# -- 45  of  50
# Time : 214.26 seconds.
# Time since last print : 26.64 seconds.
# -- 50  of  50
# Time : 241.93 seconds.
# Time since last print : 27.68 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 03:05:00 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 119
# ============================================================
# RUN STARTED :  Sun May 10 03:00:57 2020
# INIT DONE :    Sun May 10 03:00:57 2020
# RUN DONE :     Sun May 10 03:05:01 2020
# ============================================================
# Total execution time : 00:04:03
# ============================================================
# Number of files in directory 50_by_100/ : 119
# --------------------------------------------------
# BUILD Start time :  Sun May 10 03:05:02 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 28.25 seconds.
# Time since last print : 28.25 seconds.
# -- 10  of  50
# Time : 47.68 seconds.
# Time since last print : 19.43 seconds.
# -- 15  of  50
# Time : 71.17 seconds.
# Time since last print : 23.48 seconds.
# -- 20  of  50
# Time : 100.06 seconds.
# Time since last print : 28.89 seconds.
# -- 25  of  50
# Time : 127.04 seconds.
# Time since last print : 26.98 seconds.
# -- 30  of  50
# Time : 155.69 seconds.
# Time since last print : 28.65 seconds.
# -- 35  of  50
# Time : 183.47 seconds.
# Time since last print : 27.78 seconds.
# -- 40  of  50
# Time : 211.22 seconds.
# Time since last print : 27.76 seconds.
# -- 45  of  50
# Time : 234.19 seconds.
# Time since last print : 22.97 seconds.
# -- 50  of  50
# Time : 257.39 seconds.
# Time since last print : 23.20 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 03:09:20 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 120
# ============================================================
# RUN STARTED :  Sun May 10 03:05:01 2020
# INIT DONE :    Sun May 10 03:05:02 2020
# RUN DONE :     Sun May 10 03:09:21 2020
# ============================================================
# Total execution time : 00:04:18
# ============================================================
# Number of files in directory 50_by_100/ : 120
# --------------------------------------------------
# BUILD Start time :  Sun May 10 03:09:22 2020
# --------------------------------------------------
# -- 5  of  50
# Time : 30.93 seconds.
# Time since last print : 30.93 seconds.
# -- 10  of  50
# Time : 57.70 seconds.
# Time since last print : 26.77 seconds.
# -- 15  of  50
# Time : 81.40 seconds.
# Time since last print : 23.70 seconds.
# -- 20  of  50
# Time : 110.48 seconds.
# Time since last print : 29.07 seconds.
# -- 25  of  50
# Time : 137.60 seconds.
# Time since last print : 27.12 seconds.
# -- 30  of  50
# Time : 166.51 seconds.
# Time since last print : 28.92 seconds.
# -- 35  of  50
# Time : 193.92 seconds.
# Time since last print : 27.41 seconds.
# -- 40  of  50
# Time : 222.55 seconds.
# Time since last print : 28.63 seconds.
# -- 45  of  50
# Time : 249.98 seconds.
# Time since last print : 27.43 seconds.
# -- 50  of  50
# Time : 277.81 seconds.
# Time since last print : 27.83 seconds.
# --------------------------------------------------
# BUILD End time :  Sun May 10 03:14:00 2020
# --------------------------------------------------
# Number of files in directory 50_by_100/ : 121
# ============================================================
# RUN STARTED :  Sun May 10 03:09:21 2020
# INIT DONE :    Sun May 10 03:09:22 2020
# RUN DONE :     Sun May 10 03:14:01 2020
# ============================================================
# Total execution time : 00:04:39
# ============================================================
# ============================================================
# ============================================================
# PROGRAM DONE :  Sun May 10 03:14:01 2020
# PROGRAM DONE IN 03:43:21 seconds

# %%
done_diseases, done_targets, n_files, _ = get_csvs(dir_info = dir_info,
                                                           directory = directory,
                                                           file_prefix = file_prefix,
                                                           file_suffix = file_suffix)

print('Done diseases : ', len(done_diseases))
print('Unique diseases : ', len(np.unique(done_diseases)))

import collections
print('============================================================')
print('Duplicates : ', [item for item, count in collections.Counter(done_diseases).items() if count > 1])
