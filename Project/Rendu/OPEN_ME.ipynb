# %% [markdown]
# # Data Science in Practice 2020
#
# *MGT-415*
#
# ## Project
#
# ### Descriptive report
#
# Authors :
# - Rayan Chaouche
# - Yann Martinson
# - Christopher Padovani
# - Jules Triomphe
#
# ## Summary
#
# ### PDF Report
#
# [COVID-19 : Risk-factor Prediction](./MGT_415_Cord19.pdf)
#
# ### Data
#
# [IDS1](./Kaggle/COVID_KG_sample.csv)
#
# [IDS2](./Kaggle/predicted_covid19_risk_factors.csv)
#
# [DS1](./50_by_100/Full-2020_05_10-13_14_09-X_raw_disease_50_target_100_7217_by_101.csv)
#
# ### Code & Scripts
#
# Multiple jupyter notebooks were used to complete this project. They are available below :
#
# The code to create the new data-set (DS1)
#
# - [Notebook](./00_Create_Datasets.ipynb)
# - [HTML](./00_Create_Datasets.html)
#
# The network analysis
#
# - [Notebook](./Network/disease_target_network.ipynb)
# - [HTML](./Network/disease_target_network.html)
#
# The grid search algorithm
#
# - [Notebook](./01_Grid_Search.ipynb)
# - [HTML](./01_Grid_Search.html)
#
# The random search algorithm
#
# - [Notebook](./02_Random_Search.ipynb)
# - [HTML](./02_Random_Search.html)
#
# ### Video
#
# [Link](./Video.mp4)
#
# ### Extra
#
# We have included the slides for your convenience.
#
# - [PowerPoint](./Slides.pptx)
# - [PDF](./Slides.pdf)
