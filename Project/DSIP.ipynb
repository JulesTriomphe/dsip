# %% [markdown]
# # Project

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import parallel computing libraries

# %%
from ipyparallel import Client
from ipyparallel.joblib import IPythonParallelBackend
from joblib import Parallel, parallel_backend, register_parallel_backend

# %%
c = Client(profile='default')
print('profile:', c.profile)
print("IDs:", c.ids) # Process id numbers
bview = c.load_balanced_view()
register_parallel_backend('ipyparallel',
                          lambda : IPythonParallelBackend(view=bview))
# Out:
# profile: default
# IDs: [0, 1, 2, 3]

# %% [markdown]
# Read datasets

# %%
predictions = pd.read_csv('predicted_covid19_risk_factors.csv')
targets = pd.read_csv('https://storage.googleapis.com/open-targets-data-releases/20.02/output/20.02_target_list.csv.gz',
                          compression='gzip')
diseases = pd.read_csv('https://storage.googleapis.com/open-targets-data-releases/20.02/output/20.02_disease_list.csv.gz',
                           compression='gzip')

# %% [markdown]
# Explore predictions dataset

# %%
predictions.head()
# Out:
#    Unnamed: 0                                  Risk Factors     Score
# 0           0                 Platelet storage pool disease  0.852844
# 1           1  abnormality of the urinary system physiology  0.828951
# 2           2                                 Bronchiolitis  0.781315
# 3           3                      endocrine system disease  0.774616
# 4           4                                        Hernia  0.766383

# %% [markdown]
# Describe predictions dataset

# %%
predictions['Risk Factors'].describe()
# Out:
# count                                                  7217
# unique                                                 7217
# top       46,XX disorder of sex development induced by a...
# freq                                                      1
# Name: Risk Factors, dtype: object

# %%
diseases.head()
# Out:
#           efo_id                       disease_full_name  \
# 0    EFO_1000984           inflammatory breast carcinoma
# 1  MONDO_0004093           esophageal basaloid carcinoma
# 2    EFO_0006352       laryngeal squamous cell carcinoma
# 3    EFO_1000514  Salivary Gland Adenosquamous Carcinoma
# 4    EFO_1001965      pharyngeal squamous cell carcinoma
#
#    number_of_associations
# 0                     174
# 1                       1
# 2                     796
# 3                       0
# 4                     428

# %%
#test = diseases.sort_values(by = 'efo_id')
#test.disease_full_name.tolist().index('inflammatory breast carcinoma')

# %%
prediction_extended = predictions.merge(diseases,
                              how = 'left',
                              left_on = 'Risk Factors',
                              right_on = 'disease_full_name')[['efo_id', 'disease_full_name', 'Score']]
prediction_extended.sort_values(by = 'efo_id', inplace = True, ascending = True)
prediction_extended.reset_index(inplace=True, drop = True)
prediction_extended.head()
# Out:
#          efo_id                    disease_full_name     Score
# 0  DOID_0050890                      synucleinopathy  0.001827
# 1   EFO_0000094  B-cell acute lymphoblastic leukemia  0.001435
# 2   EFO_0000095         chronic lymphocytic leukemia  0.002511
# 3   EFO_0000096           neoplasm of mature B-cells  0.003721
# 4   EFO_0000174                        Ewing sarcoma  0.000201

# %%
prediction_extended.Score[prediction_extended.efo_id.tolist().index('EFO_0000094')]
# Out:
# 0.0014345049858093262

# %%
target_list = np.random.choice(list(targets.ensembl_id.tolist()), 1000).tolist()
disease_list = prediction_extended.efo_id.tolist()

target_list.sort()
disease_list.sort()

print(len(target_list))
print(len(disease_list))

features = target_list + disease_list
# Out:
# ['ENSG00000002726', 'ENSG00000005884', 'ENSG00000007541', 'ENSG00000007952', 'ENSG00000008516', 'ENSG00000010072', 'ENSG00000013392', 'ENSG00000019144', 'ENSG00000035862', 'ENSG00000039523']
# ['DOID_0050890', 'EFO_0000094', 'EFO_0000095', 'EFO_0000096', 'EFO_0000174', 'EFO_0000178', 'EFO_0000180', 'EFO_0000181', 'EFO_0000182', 'EFO_0000183']
# ----------
# 1000
# 7217

# %%
X_raw = np.empty((len(disease_list),
                  len(target_list) + 1))

from opentargets import OpenTargetsClient
from time import time

ot = OpenTargetsClient()
start_time = time()
tmp_time = time()

with parallel_backend('ipyparallel'):
    for disease_id, disease_n in zip(disease_list, range(len(disease_list))):
        for target_id,target_n in zip(target_list, range(len(target_list))):            
            search = ot.filter_associations(disease = disease_id,
                                        target = target_id,
                                        fields = ['association_score.overall', 'target.id', 'disease.id'])
            for i, r in enumerate(search):
                if len(search) > 0 and r['disease']['id'] == disease_id:
                    X_raw[disease_n][target_n] = r['association_score']['overall']
                    #print(r['disease']['id'], r['target']['id'], r['association_score']['overall'])
                else:
                    X_raw[disease_n][target_n] = 0
            if (target_n + 1) % 500 == 0:
                print('X_raw line creation : {:.2f} % done. '.format((target_n + 1) / len(target_list) * 100))
                print(target_n + 1, ' of ', len(target_list))
                print('Time : {:.2f} seconds.'.format(time() - tmp_time))
                tmp_time = time()
        X_raw[disease_n][len(target_list)] = prediction_extended.Score[disease_n]
        print('-----X_raw creation : {:.2f} % done.'.format((disease_n + 1) / len(disease_list) * 100))
        print(disease_n + 1, ' of ', len(disease_list))
pd.DataFrame(X_raw).to_csv("test/X_raw.csv")
# Out:
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 5.63 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 5.74 seconds.
# -----X_raw creation : 0.01 % done.
# 1  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 5.31 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 5.29 seconds.
# -----X_raw creation : 0.03 % done.
# 2  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 5.68 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 5.77 seconds.
# -----X_raw creation : 0.04 % done.
# 3  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 15.48 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.19 seconds.
# -----X_raw creation : 0.06 % done.
# 4  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.45 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.62 seconds.
# -----X_raw creation : 0.07 % done.
# 5  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.58 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.53 seconds.
# -----X_raw creation : 0.08 % done.
# 6  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.39 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.55 seconds.
# -----X_raw creation : 0.10 % done.
# 7  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.91 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.94 seconds.
# -----X_raw creation : 0.11 % done.
# 8  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.30 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.05 seconds.
# -----X_raw creation : 0.12 % done.
# 9  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.23 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.93 seconds.
# -----X_raw creation : 0.14 % done.
# 10  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.21 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.58 seconds.
# -----X_raw creation : 0.15 % done.
# 11  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.67 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.47 seconds.
# -----X_raw creation : 0.17 % done.
# 12  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.60 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.11 seconds.
# -----X_raw creation : 0.18 % done.
# 13  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 50.46 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.51 seconds.
# -----X_raw creation : 0.19 % done.
# 14  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.87 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.94 seconds.
# -----X_raw creation : 0.21 % done.
# 15  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 50.17 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.05 seconds.
# -----X_raw creation : 0.22 % done.
# 16  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.46 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.13 seconds.
# -----X_raw creation : 0.24 % done.
# 17  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.18 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.87 seconds.
# -----X_raw creation : 0.25 % done.
# 18  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.64 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.03 seconds.
# -----X_raw creation : 0.26 % done.
# 19  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.80 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.20 seconds.
# -----X_raw creation : 0.28 % done.
# 20  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.74 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.12 seconds.
# -----X_raw creation : 0.29 % done.
# 21  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.40 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.46 seconds.
# -----X_raw creation : 0.30 % done.
# 22  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 75.82 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.62 seconds.
# -----X_raw creation : 0.32 % done.
# 23  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.44 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.98 seconds.
# -----X_raw creation : 0.33 % done.
# 24  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.57 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.49 seconds.
# -----X_raw creation : 0.35 % done.
# 25  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 50.01 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.20 seconds.
# -----X_raw creation : 0.36 % done.
# 26  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.94 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.66 seconds.
# -----X_raw creation : 0.37 % done.
# 27  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.00 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.67 seconds.
# -----X_raw creation : 0.39 % done.
# 28  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.68 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.60 seconds.
# -----X_raw creation : 0.40 % done.
# 29  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.29 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.30 seconds.
# -----X_raw creation : 0.42 % done.
# 30  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.77 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.61 seconds.
# -----X_raw creation : 0.43 % done.
# 31  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.17 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.90 seconds.
# -----X_raw creation : 0.44 % done.
# 32  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 77.88 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.57 seconds.
# -----X_raw creation : 0.46 % done.
# 33  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 61.60 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.39 seconds.
# -----X_raw creation : 0.47 % done.
# 34  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 50.08 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.95 seconds.
# -----X_raw creation : 0.48 % done.
# 35  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.23 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.43 seconds.
# -----X_raw creation : 0.50 % done.
# 36  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.79 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.49 seconds.
# -----X_raw creation : 0.51 % done.
# 37  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.76 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 46.85 seconds.
# -----X_raw creation : 0.53 % done.
# 38  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 71.01 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 37.40 seconds.
# -----X_raw creation : 0.54 % done.
# 39  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 54.10 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.55 seconds.
# -----X_raw creation : 0.55 % done.
# 40  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 58.49 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 40.97 seconds.
# -----X_raw creation : 0.57 % done.
# 41  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 59.19 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 38.53 seconds.
# -----X_raw creation : 0.58 % done.
# 42  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.11 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 39.10 seconds.
# -----X_raw creation : 0.60 % done.
# 43  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 54.84 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 35.46 seconds.
# -----X_raw creation : 0.61 % done.
# 44  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.86 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.17 seconds.
# -----X_raw creation : 0.62 % done.
# 45  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 53.73 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 36.84 seconds.
# -----X_raw creation : 0.64 % done.
# 46  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.20 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 39.76 seconds.
# -----X_raw creation : 0.65 % done.
# 47  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 56.46 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.88 seconds.
# -----X_raw creation : 0.67 % done.
# 48  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.27 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 36.88 seconds.
# -----X_raw creation : 0.68 % done.
# 49  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.87 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 36.98 seconds.
# -----X_raw creation : 0.69 % done.
# 50  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 55.08 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.34 seconds.
# -----X_raw creation : 0.71 % done.
# 51  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.32 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 36.55 seconds.
# -----X_raw creation : 0.72 % done.
# 52  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.05 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.38 seconds.
# -----X_raw creation : 0.73 % done.
# 53  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.30 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.69 seconds.
# -----X_raw creation : 0.75 % done.
# 54  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.03 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 35.37 seconds.
# -----X_raw creation : 0.76 % done.
# 55  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.29 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 35.53 seconds.
# -----X_raw creation : 0.78 % done.
# 56  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.91 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.58 seconds.
# -----X_raw creation : 0.79 % done.
# 57  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.07 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 28.32 seconds.
# -----X_raw creation : 0.80 % done.
# 58  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 45.80 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.94 seconds.
# -----X_raw creation : 0.82 % done.
# 59  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 44.61 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.88 seconds.
# -----X_raw creation : 0.83 % done.
# 60  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 42.66 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.56 seconds.
# -----X_raw creation : 0.85 % done.
# 61  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 39.27 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 28.00 seconds.
# -----X_raw creation : 0.86 % done.
# 62  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 38.21 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 36.75 seconds.
# -----X_raw creation : 0.87 % done.
# 63  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.09 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.03 seconds.
# -----X_raw creation : 0.89 % done.
# 64  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 44.37 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.13 seconds.
# -----X_raw creation : 0.90 % done.
# 65  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.38 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.80 seconds.
# -----X_raw creation : 0.91 % done.
# 66  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 44.36 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.25 seconds.
# -----X_raw creation : 0.93 % done.
# 67  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.65 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.26 seconds.
# -----X_raw creation : 0.94 % done.
# 68  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 40.86 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.44 seconds.
# -----X_raw creation : 0.96 % done.
# 69  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.47 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.53 seconds.
# -----X_raw creation : 0.97 % done.
# 70  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 45.04 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.82 seconds.
# -----X_raw creation : 0.98 % done.
# 71  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 44.11 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.64 seconds.
# -----X_raw creation : 1.00 % done.
# 72  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 45.72 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.40 seconds.
# -----X_raw creation : 1.01 % done.
# 73  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 38.53 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.67 seconds.
# -----X_raw creation : 1.03 % done.
# 74  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 40.31 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 27.54 seconds.
# -----X_raw creation : 1.04 % done.
# 75  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 39.16 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.18 seconds.
# -----X_raw creation : 1.05 % done.
# 76  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 37.47 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.46 seconds.
# -----X_raw creation : 1.07 % done.
# 77  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 35.10 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 25.71 seconds.
# -----X_raw creation : 1.08 % done.
# 78  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 33.91 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 26.37 seconds.
# -----X_raw creation : 1.09 % done.
# 79  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 36.11 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 27.00 seconds.
# -----X_raw creation : 1.11 % done.
# 80  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 36.31 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 25.21 seconds.
# -----X_raw creation : 1.12 % done.
# 81  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 35.67 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 26.89 seconds.
# -----X_raw creation : 1.14 % done.
# 82  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 35.95 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 25.18 seconds.
# -----X_raw creation : 1.15 % done.
# 83  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 35.74 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 25.09 seconds.
# -----X_raw creation : 1.16 % done.
# 84  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 39.82 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.99 seconds.
# -----X_raw creation : 1.18 % done.
# 85  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.81 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.47 seconds.
# -----X_raw creation : 1.19 % done.
# 86  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.49 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.31 seconds.
# -----X_raw creation : 1.21 % done.
# 87  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.37 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.85 seconds.
# -----X_raw creation : 1.22 % done.
# 88  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.99 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.52 seconds.
# -----X_raw creation : 1.23 % done.
# 89  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 50.13 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.39 seconds.
# -----X_raw creation : 1.25 % done.
# 90  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.35 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.97 seconds.
# -----X_raw creation : 1.26 % done.
# 91  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.97 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.48 seconds.
# -----X_raw creation : 1.27 % done.
# 92  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.62 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.59 seconds.
# -----X_raw creation : 1.29 % done.
# 93  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.20 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.74 seconds.
# -----X_raw creation : 1.30 % done.
# 94  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 47.27 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.49 seconds.
# -----X_raw creation : 1.32 % done.
# 95  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.10 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.32 seconds.
# -----X_raw creation : 1.33 % done.
# 96  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.35 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.29 seconds.
# -----X_raw creation : 1.34 % done.
# 97  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 46.86 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 29.71 seconds.
# -----X_raw creation : 1.36 % done.
# 98  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.12 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 35.92 seconds.
# -----X_raw creation : 1.37 % done.
# 99  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 53.28 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.44 seconds.
# -----X_raw creation : 1.39 % done.
# 100  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 50.52 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.66 seconds.
# -----X_raw creation : 1.40 % done.
# 101  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.25 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.64 seconds.
# -----X_raw creation : 1.41 % done.
# 102  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.27 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 35.03 seconds.
# -----X_raw creation : 1.43 % done.
# 103  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.56 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.32 seconds.
# -----X_raw creation : 1.44 % done.
# 104  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.72 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 30.75 seconds.
# -----X_raw creation : 1.45 % done.
# 105  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 48.58 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.91 seconds.
# -----X_raw creation : 1.47 % done.
# 106  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.25 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 31.61 seconds.
# -----X_raw creation : 1.48 % done.
# 107  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.84 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.21 seconds.
# -----X_raw creation : 1.50 % done.
# 108  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.63 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 37.03 seconds.
# -----X_raw creation : 1.51 % done.
# 109  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 56.36 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 41.83 seconds.
# -----X_raw creation : 1.52 % done.
# 110  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 55.56 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.13 seconds.
# -----X_raw creation : 1.54 % done.
# 111  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 56.86 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.97 seconds.
# -----X_raw creation : 1.55 % done.
# 112  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 52.96 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 35.64 seconds.
# -----X_raw creation : 1.57 % done.
# 113  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 53.61 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 33.88 seconds.
# -----X_raw creation : 1.58 % done.
# 114  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 51.97 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 34.85 seconds.
# -----X_raw creation : 1.59 % done.
# 115  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 53.39 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 36.05 seconds.
# -----X_raw creation : 1.61 % done.
# 116  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.20 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 40.37 seconds.
# -----X_raw creation : 1.62 % done.
# 117  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 64.47 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 41.86 seconds.
# -----X_raw creation : 1.64 % done.
# 118  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 61.29 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 40.72 seconds.
# -----X_raw creation : 1.65 % done.
# 119  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 65.37 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 42.17 seconds.
# -----X_raw creation : 1.66 % done.
# 120  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 60.12 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 41.23 seconds.
# -----X_raw creation : 1.68 % done.
# 121  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 55.90 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 32.66 seconds.
# -----X_raw creation : 1.69 % done.
# 122  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 53.77 seconds.
# X_raw line creation : 100.00 % done.
# 1000  of  1000
# Time : 38.46 seconds.
# -----X_raw creation : 1.70 % done.
# 123  of  7217
# X_raw line creation : 50.00 % done.
# 500  of  1000
# Time : 49.00 seconds.
