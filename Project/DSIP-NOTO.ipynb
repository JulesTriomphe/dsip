# %% [markdown]
# # Project

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import parallel computing libraries

# %%
from ipyparallel import Client
from ipyparallel.joblib import IPythonParallelBackend
from joblib import Parallel, parallel_backend, register_parallel_backend

# %%
c = Client(profile='default')
print('profile:', c.profile)
print("IDs:", c.ids) # Process id numbers
bview = c.load_balanced_view()
register_parallel_backend('ipyparallel',
                          lambda : IPythonParallelBackend(view=bview))
# Out:
# profile: default
# IDs: [0, 1, 2, 3]

# %% [markdown]
# Read datasets

# %%
predictions = pd.read_csv('predicted_covid19_risk_factors.csv')
targets = pd.read_csv('https://storage.googleapis.com/open-targets-data-releases/20.02/output/20.02_target_list.csv.gz',
                          compression='gzip')
diseases = pd.read_csv('https://storage.googleapis.com/open-targets-data-releases/20.02/output/20.02_disease_list.csv.gz',
                           compression='gzip')

# %% [markdown]
# Explore predictions dataset

# %%
predictions.head()
# Out:
#    Unnamed: 0                                  Risk Factors     Score
# 0           0                 Platelet storage pool disease  0.852844
# 1           1  abnormality of the urinary system physiology  0.828951
# 2           2                                 Bronchiolitis  0.781315
# 3           3                      endocrine system disease  0.774616
# 4           4                                        Hernia  0.766383

# %% [markdown]
# Describe predictions dataset

# %%
predictions['Risk Factors'].describe()
# Out:
# count                  7217
# unique                 7217
# top       Citrin deficiency
# freq                      1
# Name: Risk Factors, dtype: object

# %%
diseases.head()
# Out:
#           efo_id                       disease_full_name  \
# 0    EFO_1000984           inflammatory breast carcinoma
# 1  MONDO_0004093           esophageal basaloid carcinoma
# 2    EFO_0006352       laryngeal squamous cell carcinoma
# 3    EFO_1000514  Salivary Gland Adenosquamous Carcinoma
# 4    EFO_1001965      pharyngeal squamous cell carcinoma
#
#    number_of_associations
# 0                     174
# 1                       1
# 2                     796
# 3                       0
# 4                     428

# %%
#test = diseases.sort_values(by = 'efo_id')
#test.disease_full_name.tolist().index('inflammatory breast carcinoma')

# %%
prediction_extended = predictions.merge(diseases,
                              how = 'left',
                              left_on = 'Risk Factors',
                              right_on = 'disease_full_name')[['efo_id', 'disease_full_name', 'Score']]
prediction_extended.sort_values(by = 'efo_id', inplace = True, ascending = True)
prediction_extended.reset_index(inplace=True, drop = True)
prediction_extended.head()
# Out:
#          efo_id                    disease_full_name     Score
# 0  DOID_0050890                      synucleinopathy  0.001827
# 1   EFO_0000094  B-cell acute lymphoblastic leukemia  0.001435
# 2   EFO_0000095         chronic lymphocytic leukemia  0.002511
# 3   EFO_0000096           neoplasm of mature B-cells  0.003721
# 4   EFO_0000174                        Ewing sarcoma  0.000201

# %%
prediction_extended.Score[prediction_extended.efo_id.tolist().index('EFO_0000094')]
# Out:
# 0.0014345049858093262

# %%
target_list = np.random.choice(list(targets.ensembl_id.tolist()), 200).tolist()
disease_list = np.random.choice(list(prediction_extended.efo_id.tolist()), 200).tolist()

target_list.sort()
disease_list.sort()

print(len(target_list))
print(len(disease_list))

features = target_list + disease_list
# Out:
# 200
# 200

# %%
X_raw = np.zeros((len(disease_list),
                  len(target_list) + 1))

from opentargets import OpenTargetsClient
from time import time

ot = OpenTargetsClient()
start_time = time()
tmp_time = time()

with parallel_backend('ipyparallel'):
    for disease_id, disease_n in zip(disease_list, range(len(disease_list))):
        for target_id,target_n in zip(target_list, range(len(target_list))):            
            search = ot.filter_associations(disease = disease_id,
                                        target = target_id,
                                        fields = ['association_score.overall', 'target.id', 'disease.id'])
            for i, r in enumerate(search):
                if len(search) > 0 and r['disease']['id'] == disease_id:
                    X_raw[disease_n][target_n] = r['association_score']['overall']
                    #print(r['disease']['id'], r['target']['id'], r['association_score']['overall'])
            #if (target_n + 1) % 200 == 0:
            #    print('X_raw line creation : {:.2f} % done. '.format((target_n + 1) / len(target_list) * 100))
            #    print(target_n + 1, ' of ', len(target_list))
            #    print('Time : {:.2f} seconds.'.format(time() - tmp_time))
            #    tmp_time = time()
        X_raw[disease_n][len(target_list)] = prediction_extended.Score[disease_n]
        print('-----X_raw creation : {:.2f} % done.'.format((disease_n + 1) / len(disease_list) * 100))
        print('-----', disease_n + 1, ' of ', len(disease_list))
        if (disease_n + 1) % 5 == 0:
            print('---Time : {:.2f} seconds.'.format(time() - start_time))
            print('---Time since last print : {:.2f} seconds.'.format(time() - tmp_time))
            tmp_time = time()
# Out:
# -----X_raw creation : 0.50 % done.
# ----- 1  of  200
# -----X_raw creation : 1.00 % done.
# ----- 2  of  200
# -----X_raw creation : 1.50 % done.
# ----- 3  of  200
# -----X_raw creation : 2.00 % done.
# ----- 4  of  200
# -----X_raw creation : 2.50 % done.
# ----- 5  of  200
# ---Time : 87.20 seconds.
# ---Time since last print : 87.20 seconds.
# -----X_raw creation : 3.00 % done.
# ----- 6  of  200
# -----X_raw creation : 3.50 % done.
# ----- 7  of  200
# -----X_raw creation : 4.00 % done.
# ----- 8  of  200
# -----X_raw creation : 4.50 % done.
# ----- 9  of  200
# -----X_raw creation : 5.00 % done.
# ----- 10  of  200
# ---Time : 182.06 seconds.
# ---Time since last print : 94.85 seconds.
# -----X_raw creation : 5.50 % done.
# ----- 11  of  200
# -----X_raw creation : 6.00 % done.
# ----- 12  of  200
# -----X_raw creation : 6.50 % done.
# ----- 13  of  200
# -----X_raw creation : 7.00 % done.
# ----- 14  of  200
# -----X_raw creation : 7.50 % done.
# ----- 15  of  200
# ---Time : 278.05 seconds.
# ---Time since last print : 96.00 seconds.
# -----X_raw creation : 8.00 % done.
# ----- 16  of  200
# -----X_raw creation : 8.50 % done.
# ----- 17  of  200
# -----X_raw creation : 9.00 % done.
# ----- 18  of  200
# -----X_raw creation : 9.50 % done.
# ----- 19  of  200
# -----X_raw creation : 10.00 % done.
# ----- 20  of  200
# ---Time : 373.18 seconds.
# ---Time since last print : 95.13 seconds.
# -----X_raw creation : 10.50 % done.
# ----- 21  of  200
# -----X_raw creation : 11.00 % done.
# ----- 22  of  200
# -----X_raw creation : 11.50 % done.
# ----- 23  of  200
# -----X_raw creation : 12.00 % done.
# ----- 24  of  200
# -----X_raw creation : 12.50 % done.
# ----- 25  of  200
# ---Time : 463.39 seconds.
# ---Time since last print : 90.21 seconds.
# -----X_raw creation : 13.00 % done.
# ----- 26  of  200
# -----X_raw creation : 13.50 % done.
# ----- 27  of  200
# -----X_raw creation : 14.00 % done.
# ----- 28  of  200
# -----X_raw creation : 14.50 % done.
# ----- 29  of  200
# -----X_raw creation : 15.00 % done.
# ----- 30  of  200
# ---Time : 550.84 seconds.
# ---Time since last print : 87.45 seconds.
# -----X_raw creation : 15.50 % done.
# ----- 31  of  200
# -----X_raw creation : 16.00 % done.
# ----- 32  of  200
# -----X_raw creation : 16.50 % done.
# ----- 33  of  200
# -----X_raw creation : 17.00 % done.
# ----- 34  of  200
# -----X_raw creation : 17.50 % done.
# ----- 35  of  200
# ---Time : 641.13 seconds.
# ---Time since last print : 90.29 seconds.
# -----X_raw creation : 18.00 % done.
# ----- 36  of  200
# -----X_raw creation : 18.50 % done.
# ----- 37  of  200
# -----X_raw creation : 19.00 % done.
# ----- 38  of  200
# -----X_raw creation : 19.50 % done.
# ----- 39  of  200
# -----X_raw creation : 20.00 % done.
# ----- 40  of  200
# ---Time : 727.29 seconds.
# ---Time since last print : 86.15 seconds.
# -----X_raw creation : 20.50 % done.
# ----- 41  of  200
# -----X_raw creation : 21.00 % done.
# ----- 42  of  200
# -----X_raw creation : 21.50 % done.
# ----- 43  of  200
# -----X_raw creation : 22.00 % done.
# ----- 44  of  200
# -----X_raw creation : 22.50 % done.
# ----- 45  of  200
# ---Time : 807.77 seconds.
# ---Time since last print : 80.49 seconds.
# -----X_raw creation : 23.00 % done.
# ----- 46  of  200
# -----X_raw creation : 23.50 % done.
# ----- 47  of  200
# -----X_raw creation : 24.00 % done.
# ----- 48  of  200
# -----X_raw creation : 24.50 % done.
# ----- 49  of  200
# -----X_raw creation : 25.00 % done.
# ----- 50  of  200
# ---Time : 903.58 seconds.
# ---Time since last print : 95.81 seconds.
# -----X_raw creation : 25.50 % done.
# ----- 51  of  200
# -----X_raw creation : 26.00 % done.
# ----- 52  of  200
# -----X_raw creation : 26.50 % done.
# ----- 53  of  200
# -----X_raw creation : 27.00 % done.
# ----- 54  of  200
# -----X_raw creation : 27.50 % done.
# ----- 55  of  200
# ---Time : 1006.75 seconds.
# ---Time since last print : 103.17 seconds.
# -----X_raw creation : 28.00 % done.
# ----- 56  of  200
# -----X_raw creation : 28.50 % done.
# ----- 57  of  200
# -----X_raw creation : 29.00 % done.
# ----- 58  of  200
# -----X_raw creation : 29.50 % done.
# ----- 59  of  200
# -----X_raw creation : 30.00 % done.
# ----- 60  of  200
# ---Time : 1116.18 seconds.
# ---Time since last print : 109.43 seconds.
# -----X_raw creation : 30.50 % done.
# ----- 61  of  200
# -----X_raw creation : 31.00 % done.
# ----- 62  of  200
# -----X_raw creation : 31.50 % done.
# ----- 63  of  200
# -----X_raw creation : 32.00 % done.
# ----- 64  of  200
# -----X_raw creation : 32.50 % done.
# ----- 65  of  200
# ---Time : 1204.62 seconds.
# ---Time since last print : 88.44 seconds.
# -----X_raw creation : 33.00 % done.
# ----- 66  of  200
# -----X_raw creation : 33.50 % done.
# ----- 67  of  200
# -----X_raw creation : 34.00 % done.
# ----- 68  of  200
# -----X_raw creation : 34.50 % done.
# ----- 69  of  200
# -----X_raw creation : 35.00 % done.
# ----- 70  of  200
# ---Time : 1309.62 seconds.
# ---Time since last print : 105.00 seconds.
# -----X_raw creation : 35.50 % done.
# ----- 71  of  200
# -----X_raw creation : 36.00 % done.
# ----- 72  of  200
# -----X_raw creation : 36.50 % done.
# ----- 73  of  200
# -----X_raw creation : 37.00 % done.
# ----- 74  of  200
# -----X_raw creation : 37.50 % done.
# ----- 75  of  200
# ---Time : 1399.71 seconds.
# ---Time since last print : 90.08 seconds.
# -----X_raw creation : 38.00 % done.
# ----- 76  of  200
# -----X_raw creation : 38.50 % done.
# ----- 77  of  200
# -----X_raw creation : 39.00 % done.
# ----- 78  of  200
# -----X_raw creation : 39.50 % done.
# ----- 79  of  200
# -----X_raw creation : 40.00 % done.
# ----- 80  of  200
# ---Time : 1488.69 seconds.
# ---Time since last print : 88.98 seconds.
# -----X_raw creation : 40.50 % done.
# ----- 81  of  200
# -----X_raw creation : 41.00 % done.
# ----- 82  of  200
# -----X_raw creation : 41.50 % done.
# ----- 83  of  200
# -----X_raw creation : 42.00 % done.
# ----- 84  of  200
# -----X_raw creation : 42.50 % done.
# ----- 85  of  200
# ---Time : 1575.08 seconds.
# ---Time since last print : 86.39 seconds.
# -----X_raw creation : 43.00 % done.
# ----- 86  of  200
# -----X_raw creation : 43.50 % done.
# ----- 87  of  200
# -----X_raw creation : 44.00 % done.
# ----- 88  of  200
# -----X_raw creation : 44.50 % done.
# ----- 89  of  200
# -----X_raw creation : 45.00 % done.
# ----- 90  of  200
# ---Time : 1656.67 seconds.
# ---Time since last print : 81.59 seconds.
# -----X_raw creation : 45.50 % done.
# ----- 91  of  200
# -----X_raw creation : 46.00 % done.
# ----- 92  of  200
# -----X_raw creation : 46.50 % done.
# ----- 93  of  200
# -----X_raw creation : 47.00 % done.
# ----- 94  of  200
# -----X_raw creation : 47.50 % done.
# ----- 95  of  200
# ---Time : 1729.04 seconds.
# ---Time since last print : 72.37 seconds.
# -----X_raw creation : 48.00 % done.
# ----- 96  of  200
# -----X_raw creation : 48.50 % done.
# ----- 97  of  200
# -----X_raw creation : 49.00 % done.
# ----- 98  of  200
# -----X_raw creation : 49.50 % done.
# ----- 99  of  200
# -----X_raw creation : 50.00 % done.
# ----- 100  of  200
# ---Time : 1831.88 seconds.
# ---Time since last print : 102.84 seconds.
# -----X_raw creation : 50.50 % done.
# ----- 101  of  200
# -----X_raw creation : 51.00 % done.
# ----- 102  of  200
# -----X_raw creation : 51.50 % done.
# ----- 103  of  200
# -----X_raw creation : 52.00 % done.
# ----- 104  of  200
# -----X_raw creation : 52.50 % done.
# ----- 105  of  200
# ---Time : 1923.77 seconds.
# ---Time since last print : 91.89 seconds.
# -----X_raw creation : 53.00 % done.
# ----- 106  of  200
# -----X_raw creation : 53.50 % done.
# ----- 107  of  200
# -----X_raw creation : 54.00 % done.
# ----- 108  of  200
# -----X_raw creation : 54.50 % done.
# ----- 109  of  200
# -----X_raw creation : 55.00 % done.
# ----- 110  of  200
# ---Time : 2009.53 seconds.
# ---Time since last print : 85.76 seconds.
# -----X_raw creation : 55.50 % done.
# ----- 111  of  200
# -----X_raw creation : 56.00 % done.
# ----- 112  of  200
# -----X_raw creation : 56.50 % done.
# ----- 113  of  200
# -----X_raw creation : 57.00 % done.
# ----- 114  of  200
# -----X_raw creation : 57.50 % done.
# ----- 115  of  200
# ---Time : 2117.13 seconds.
# ---Time since last print : 107.61 seconds.
# -----X_raw creation : 58.00 % done.
# ----- 116  of  200
# -----X_raw creation : 58.50 % done.
# ----- 117  of  200
# -----X_raw creation : 59.00 % done.
# ----- 118  of  200
# -----X_raw creation : 59.50 % done.
# ----- 119  of  200
# -----X_raw creation : 60.00 % done.
# ----- 120  of  200
# ---Time : 2233.01 seconds.
# ---Time since last print : 115.87 seconds.
# -----X_raw creation : 60.50 % done.
# ----- 121  of  200
# -----X_raw creation : 61.00 % done.
# ----- 122  of  200
# -----X_raw creation : 61.50 % done.
# ----- 123  of  200
# -----X_raw creation : 62.00 % done.
# ----- 124  of  200
# -----X_raw creation : 62.50 % done.
# ----- 125  of  200
# ---Time : 2350.93 seconds.
# ---Time since last print : 117.93 seconds.
# -----X_raw creation : 63.00 % done.
# ----- 126  of  200
# -----X_raw creation : 63.50 % done.
# ----- 127  of  200

# %%
pd.DataFrame(X_raw, index = disease_list, columns = disease_list + ['COVID']).to_csv("test/X_raw_short.csv")

# %%
pd.DataFrame(X_raw).head()
